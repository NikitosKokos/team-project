# %%
import cv2
import mediapipe as mp
import os
import json
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
import cv2
import mediapipe as mp
import os
import json
import numpy as np

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Placeholder for the directory containing the videos
video_path = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/keypoint_videos_augmented"

# Function to calculate angle between three points
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Second point (vertex)
    c = np.array(c)  # Third point
    ba = a - b
    bc = c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.degrees(np.arccos(cosine_angle))
    return angle

# Process videos in the directory
for file in os.listdir(video_path):
    if file.endswith(".mp4"):
        video_file_path = os.path.join(video_path, file)
        cap = cv2.VideoCapture(video_file_path)

        keypoints_data = []  # Store keypoints for this video

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Convert frame to RGB
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            result = pose.process(frame_rgb)

            if result.pose_landmarks:
                landmarks = result.pose_landmarks.landmark

                # Extract relevant keypoints for the trailing leg
                hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP].x,
                       landmarks[mp_pose.PoseLandmark.LEFT_HIP].y]
                knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE].x,
                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE].y]
                ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE].x,
                         landmarks[mp_pose.PoseLandmark.LEFT_ANKLE].y]

                # Calculate angle and distance
                angle = calculate_angle(hip, knee, ankle)

                # Store data for this frame
                keypoints_data.append({
                    "frame": cap.get(cv2.CAP_PROP_POS_FRAMES),
                    "angle": angle,
                    "hip": hip,
                    "knee": knee,
                    "ankle": ankle
                })

        # Release the video
        cap.release()

        # Save keypoints to a JSON file
        json_filename = os.path.splitext(file)[0] + "_hop_phase_keypoints.json"
        json_path = os.path.join(video_path, json_filename)
        with open(json_path, "w") as json_file:
            json.dump(keypoints_data, json_file, indent=4)

print("Keypoints extraction for hop phase complete!")
# Out:
# I0000 00:00:1736608465.231470 7694878 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1736608465.299488 7702775 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736608465.313189 7702775 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Keypoints extraction for hop phase complete!

# %%
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Second point (vertex)
    c = np.array(c)  # Third point
    ba = a - b
    bc = c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    return np.degrees(np.arccos(cosine_angle))

def calculate_distance(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.linalg.norm(a - b)

# %%
import cv2
import os
import numpy as np

# Placeholder for input and output directories
input_video_path = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/keypoint_videos"
augmented_video_path = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/keypoint_videos_augmented"
os.makedirs(augmented_video_path, exist_ok=True)

# Define augmentation functions
def augment_video(video_path, output_path, augmentations):
    cap = cv2.VideoCapture(video_path)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))

    # Create an augmented video writer
    out = cv2.VideoWriter(output_path, fourcc, fps, frame_size)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Apply augmentations
        for aug in augmentations:
            augmented_frame = aug(frame)
            out.write(augmented_frame)

    cap.release()
    out.release()

# Example augmentations
def mirror(frame):
    return cv2.flip(frame, 1)

def add_noise(frame):
    noise = np.random.normal(0, 10, frame.shape).astype(np.uint8)
    return cv2.add(frame, noise)

def rotate(frame, angle=5):
    height, width = frame.shape[:2]
    matrix = cv2.getRotationMatrix2D((width // 2, height // 2), angle, 1)
    return cv2.warpAffine(frame, matrix, (width, height))

# Apply augmentations to all videos
for file in os.listdir(input_video_path):
    if file.endswith(".mp4"):
        video_file_path = os.path.join(input_video_path, file)
        base_name = os.path.splitext(file)[0]

        # Augment and save
        augment_video(video_file_path, os.path.join(augmented_video_path, f"{base_name}_mirrored.mp4"), [mirror])
        augment_video(video_file_path, os.path.join(augmented_video_path, f"{base_name}_noisy.mp4"), [add_noise])
        augment_video(video_file_path, os.path.join(augmented_video_path, f"{base_name}_rotated.mp4"), [lambda frame: rotate(frame, 5)])

# %%
import json

features = []
labels = []

# Placeholder for the JSON directory
keypoints_directory = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/keypoint_videos_augmented"

# Load JSON files and extract features
for file in os.listdir(keypoints_directory):
    if file.endswith(".json"):
        with open(os.path.join(keypoints_directory, file), "r") as f:
            data = json.load(f)

        angles = []
        distances = []

        for frame in data:
            hip = frame["hip"]
            knee = frame["knee"]
            ankle = frame["ankle"]

            # Calculate angle and distance
            angle = calculate_angle(hip, knee, ankle)
            distance = calculate_distance(hip, knee)

            angles.append(angle)
            distances.append(distance)

        # Combine features
        feature_sequence = np.stack([angles, distances], axis=1)
        features.append(feature_sequence)

        # Extract label from filename (e.g., 0, 0.5, 1)
        label = float(file.split("_")[0])  # Adjust this based on your naming convention
        labels.append(label)

# Pad sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = max(len(seq) for seq in features)
features = pad_sequences(features, maxlen=max_len, padding="post", dtype="float32")
labels = np.array(labels)

# %%
# Train-test split
X_train, X_val, y_train, y_val = train_test_split(
    features, labels, test_size=0.15, random_state=42  # Adjust split for 17 videos
)

# Reshape input for LSTM
X_train = X_train[..., np.newaxis]  # Add channel dimension for LSTM
X_val = X_val[..., np.newaxis]

print(f"Training samples: {len(X_train)}, Validation samples: {len(X_val)}")
# Out:
# Training samples: 43, Validation samples: 8

# %%
# Define the LSTM model
model = Sequential([
    LSTM(64, activation='tanh', return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.15),
    Dense(32, activation='relu'),
    Dense(1)  # Output: Regression score (0, 0.5, 1)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

# Model summary
print(model.summary())
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 64)             │        17,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,265 (75.25 KB)
#  Trainable params: 19,265 (75.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=800,  # Adjust epochs based on convergence
    batch_size=8,  # Smaller batch size for small dataset
    verbose=1
)
# Out:
# Epoch 1/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.7324 - mae: 0.7276 - val_loss: 0.9907 - val_mae: 0.9953
# Epoch 2/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7254 - mae: 0.7317 - val_loss: 0.9789 - val_mae: 0.9894
# Epoch 3/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8435 - mae: 0.8404 - val_loss: 0.9665 - val_mae: 0.9831
# Epoch 4/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7547 - mae: 0.7758 - val_loss: 0.9533 - val_mae: 0.9764
# Epoch 5/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7746 - mae: 0.8022 - val_loss: 0.9390 - val_mae: 0.9690
# Epoch 6/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8031 - mae: 0.8253 - val_loss: 0.9230 - val_mae: 0.9607
# Epoch 7/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7292 - mae: 0.7833 - val_loss: 0.9049 - val_mae: 0.9513
# Epoch 8/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6960 - mae: 0.7407 - val_loss: 0.8856 - val_mae: 0.9410
# Epoch 9/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7165 - mae: 0.7800 - val_loss: 0.8622 - val_mae: 0.9285
# Epoch 10/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7197 - mae: 0.7900 - val_loss: 0.8340 - val_mae: 0.9132
# Epoch 11/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6702 - mae: 0.7542 - val_loss: 0.7987 - val_mae: 0.8937
# Epoch 12/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6536 - mae: 0.7535 - val_loss: 0.7509 - val_mae: 0.8666
# Epoch 13/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5816 - mae: 0.7021 - val_loss: 0.6830 - val_mae: 0.8264
# Epoch 14/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5895 - mae: 0.7445 - val_loss: 0.5716 - val_mae: 0.7560
# Epoch 15/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4381 - mae: 0.6357 - val_loss: 0.3647 - val_mae: 0.6029
# Epoch 16/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3325 - mae: 0.5441 - val_loss: 0.0623 - val_mae: 0.2093
# Epoch 17/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2409 - mae: 0.3866 - val_loss: 0.0617 - val_mae: 0.2190
# Epoch 18/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2263 - mae: 0.4010 - val_loss: 0.0985 - val_mae: 0.3013
# Epoch 19/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2147 - mae: 0.3932 - val_loss: 0.0684 - val_mae: 0.2444
# Epoch 20/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1915 - mae: 0.3638 - val_loss: 0.0444 - val_mae: 0.1867
# Epoch 21/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1868 - mae: 0.3375 - val_loss: 0.0521 - val_mae: 0.2112
# Epoch 22/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2279 - mae: 0.4067 - val_loss: 0.0767 - val_mae: 0.2677
# Epoch 23/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0592 - mae: 0.1402 - val_loss: 0.1094 - val_mae: 0.1552
# Epoch 688/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0995 - mae: 0.1774 - val_loss: 0.1081 - val_mae: 0.1339
# Epoch 689/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0716 - mae: 0.1467 - val_loss: 0.1278 - val_mae: 0.2302
# Epoch 690/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0583 - mae: 0.1771 - val_loss: 0.1576 - val_mae: 0.2867
# Epoch 691/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0480 - mae: 0.1482 - val_loss: 0.1169 - val_mae: 0.1797
# Epoch 692/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0366 - mae: 0.1144 - val_loss: 0.1218 - val_mae: 0.1930
# Epoch 693/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0354 - mae: 0.1165 - val_loss: 0.1225 - val_mae: 0.1950
# Epoch 694/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0382 - mae: 0.1206 - val_loss: 0.1088 - val_mae: 0.1548
# Epoch 695/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0292 - mae: 0.1003 - val_loss: 0.1842 - val_mae: 0.2967
# Epoch 696/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0500 - mae: 0.1530 - val_loss: 0.1069 - val_mae: 0.1674
# Epoch 697/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1257 - mae: 0.2026 - val_loss: 0.1038 - val_mae: 0.1430
# Epoch 698/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0453 - mae: 0.1148 - val_loss: 0.1069 - val_mae: 0.1691
# Epoch 699/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0266 - mae: 0.0962 - val_loss: 0.1795 - val_mae: 0.3364
# Epoch 700/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0480 - mae: 0.1629 - val_loss: 0.1095 - val_mae: 0.1882
# Epoch 701/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0434 - mae: 0.1309 - val_loss: 0.1232 - val_mae: 0.2311
# Epoch 702/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0412 - mae: 0.1397 - val_loss: 0.1467 - val_mae: 0.2724
# Epoch 703/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0415 - mae: 0.1429 - val_loss: 0.1175 - val_mae: 0.1956
# Epoch 704/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0406 - mae: 0.1067 - val_loss: 0.1105 - val_mae: 0.1616
# Epoch 705/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0491 - mae: 0.1290 - val_loss: 0.1970 - val_mae: 0.3092
# Epoch 706/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0450 - mae: 0.1308 - val_loss: 0.1140 - val_mae: 0.1719
# Epoch 707/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0494 - mae: 0.1252 - val_loss: 0.1338 - val_mae: 0.2085
# Epoch 708/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0432 - mae: 0.1294 - val_loss: 0.1152 - val_mae: 0.1728
# Epoch 709/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0377 - mae: 0.1207 - val_loss: 0.1140 - val_mae: 0.1669
# Epoch 710/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0580 - mae: 0.1585 - val_loss: 0.1218 - val_mae: 0.1974
# Epoch 711/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0780 - mae: 0.1607 - val_loss: 0.1081 - val_mae: 0.1343
# Epoch 712/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0755 - mae: 0.1268 - val_loss: 0.1109 - val_mae: 0.1638
# Epoch 713/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0548 - mae: 0.1303 - val_loss: 0.1500 - val_mae: 0.2818
# Epoch 714/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0493 - mae: 0.1600 - val_loss: 0.1260 - val_mae: 0.2259
# Epoch 715/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0554 - mae: 0.1475 - val_loss: 0.1120 - val_mae: 0.1666
# Epoch 716/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0444 - mae: 0.1085 - val_loss: 0.1418 - val_mae: 0.2367
# Epoch 717/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0509 - mae: 0.1320 - val_loss: 0.1232 - val_mae: 0.1906
# Epoch 718/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0277 - mae: 0.0883 - val_loss: 0.1107 - val_mae: 0.1598
# Epoch 719/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0323 - mae: 0.1070 - val_loss: 0.1463 - val_mae: 0.2313
# Epoch 720/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0369 - mae: 0.1386 - val_loss: 0.1173 - val_mae: 0.1747
# Epoch 721/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0636 - mae: 0.1329 - val_loss: 0.1220 - val_mae: 0.2216
# Epoch 756/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0317 - mae: 0.1283 - val_loss: 0.2482 - val_mae: 0.3575
# Epoch 757/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0534 - mae: 0.1578 - val_loss: 0.1304 - val_mae: 0.2119
# Epoch 758/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0249 - mae: 0.0991 - val_loss: 0.1209 - val_mae: 0.1799
# Epoch 759/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0229 - mae: 0.0854 - val_loss: 0.2709 - val_mae: 0.3690
# Epoch 760/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0457 - mae: 0.1373 - val_loss: 0.1985 - val_mae: 0.2891
# Epoch 761/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0497 - mae: 0.1406 - val_loss: 0.1370 - val_mae: 0.2244
# Epoch 762/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0310 - mae: 0.1208 - val_loss: 0.1120 - val_mae: 0.1664
# Epoch 763/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0351 - mae: 0.1153 - val_loss: 0.1098 - val_mae: 0.1521
# Epoch 764/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0617 - mae: 0.1453 - val_loss: 0.1223 - val_mae: 0.1961
# Epoch 765/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0469 - mae: 0.1286 - val_loss: 0.1093 - val_mae: 0.1511
# Epoch 766/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0678 - mae: 0.1365 - val_loss: 0.1115 - val_mae: 0.1648
# Epoch 767/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0791 - mae: 0.1698 - val_loss: 0.3026 - val_mae: 0.4528
# Epoch 768/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0817 - mae: 0.2238 - val_loss: 0.1137 - val_mae: 0.1832
# Epoch 769/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0607 - mae: 0.1276 - val_loss: 0.1120 - val_mae: 0.1649
# Epoch 770/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0667 - mae: 0.1517 - val_loss: 0.1168 - val_mae: 0.1917
# Epoch 771/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0347 - mae: 0.1085 - val_loss: 0.1733 - val_mae: 0.3117
# Epoch 772/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0525 - mae: 0.1632 - val_loss: 0.1235 - val_mae: 0.2068
# Epoch 773/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0416 - mae: 0.1108 - val_loss: 0.1105 - val_mae: 0.1413
# Epoch 774/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1322 - mae: 0.1935 - val_loss: 0.1111 - val_mae: 0.1422
# Epoch 775/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0912 - mae: 0.1694 - val_loss: 0.1397 - val_mae: 0.2567
# Epoch 776/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0416 - mae: 0.1504 - val_loss: 0.1887 - val_mae: 0.3265
# Epoch 777/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0401 - mae: 0.1450 - val_loss: 0.1315 - val_mae: 0.2367
# Epoch 778/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0473 - mae: 0.1521 - val_loss: 0.1526 - val_mae: 0.2727
# Epoch 779/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0407 - mae: 0.1426 - val_loss: 0.1234 - val_mae: 0.1998
# Epoch 780/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0435 - mae: 0.1350 - val_loss: 0.1140 - val_mae: 0.1678
# Epoch 781/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0380 - mae: 0.1099 - val_loss: 0.1936 - val_mae: 0.2960
# Epoch 782/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0840 - mae: 0.1545 - val_loss: 0.1075 - val_mae: 0.1488
# Epoch 783/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0523 - mae: 0.1322 - val_loss: 0.1285 - val_mae: 0.2083
# Epoch 784/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0328 - mae: 0.1322 - val_loss: 0.1079 - val_mae: 0.1519
# Epoch 785/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0479 - mae: 0.1094 - val_loss: 0.1070 - val_mae: 0.1520
# Epoch 786/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0822 - mae: 0.1559 - val_loss: 0.1252 - val_mae: 0.2312
# Epoch 787/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0630 - mae: 0.1886 - val_loss: 0.2083 - val_mae: 0.3567
# Epoch 788/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0541 - mae: 0.1804 - val_loss: 0.1132 - val_mae: 0.1960
# Epoch 789/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0650 - mae: 0.1549 - val_loss: 0.1069 - val_mae: 0.1511
# Epoch 790/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0312 - mae: 0.0858 - val_loss: 0.1083 - val_mae: 0.1516
# Epoch 791/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0713 - mae: 0.1598 - val_loss: 0.2089 - val_mae: 0.3264
# Epoch 792/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0386 - mae: 0.1374 - val_loss: 0.1210 - val_mae: 0.1952
# Epoch 793/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0256 - mae: 0.0851 - val_loss: 0.1511 - val_mae: 0.2450
# Epoch 794/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0521 - mae: 0.1611 - val_loss: 0.1239 - val_mae: 0.1965
# Epoch 795/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0339 - mae: 0.0881 - val_loss: 0.1102 - val_mae: 0.1373
# Epoch 796/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0689 - mae: 0.1359 - val_loss: 0.1161 - val_mae: 0.1697
# Epoch 797/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0447 - mae: 0.1269 - val_loss: 0.1388 - val_mae: 0.2428
# Epoch 798/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0311 - mae: 0.1115 - val_loss: 0.1236 - val_mae: 0.2010
# Epoch 799/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0698 - mae: 0.1733 - val_loss: 0.1223 - val_mae: 0.1916
# Epoch 800/800
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0460 - mae: 0.1338 - val_loss: 0.1147 - val_mae: 0.1431

# %%
val_loss, val_mae = model.evaluate(X_val, y_val, verbose=0)
print(f"Validation Loss: {val_loss:.4f}, Validation MAE: {val_mae:.4f}")
# Out:
# Validation Loss: 0.1147, Validation MAE: 0.1431

# %%
model.save("shotput_stage2.keras")

# %%
# Predict scores on validation data
predictions = model.predict(X_val)

# Print predictions vs actual
for i, (pred, actual) in enumerate(zip(predictions, y_val)):
    print(f"Predicted: {pred[0]:.2f}, Actual: {actual:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predicted: 1.00, Actual: 1.00
# Predicted: 0.96, Actual: 1.00
# Predicted: 0.05, Actual: 1.00
# Predicted: 0.98, Actual: 1.00
# Predicted: 0.92, Actual: 1.00
# Predicted: 0.99, Actual: 1.00
# Predicted: 0.97, Actual: 1.00
# Predicted: 1.01, Actual: 1.00

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Function to calculate the angle between three points
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Second point (vertex)
    c = np.array(c)  # Third point
    ba = a - b
    bc = c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    return np.degrees(np.arccos(cosine_angle))

# Function to calculate distance between two points
def calculate_distance(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.linalg.norm(a - b)

# Load the trained model
model_path = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/shotput_stage2.keras"
model = load_model(model_path)

# Path to the new video
new_video_path = "/Users/cezar/Desktop/Team Project/AI/shotput_models/stage2/keypoint_videos/0_user13.mp4"  # Replace with the actual video path

# Extract features from the new video
angles = []
distances = []

cap = cv2.VideoCapture(new_video_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = pose.process(frame_rgb)

    if result.pose_landmarks:
        landmarks = result.pose_landmarks.landmark

        # Extract relevant keypoints for the trailing leg (right leg in this case)
        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_HIP].y]
        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE].x,
                      landmarks[mp_pose.PoseLandmark.RIGHT_KNEE].y]
        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE].x,
                       landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE].y]

        # Calculate angle and distance
        angle = calculate_angle(right_hip, right_knee, right_ankle)
        distance = calculate_distance(right_hip, right_knee)

        angles.append(angle)
        distances.append(distance)

cap.release()

# Combine features
features = np.stack([angles, distances], axis=1)

# Pad the sequence to match the model's input shape
features = pad_sequences([features], maxlen=model.input_shape[1], padding='post', dtype='float32')
features = features[..., np.newaxis]  # Add channel dimension for single feature

# Predict the score for the new video
predicted_score = model.predict(features)
print(f"Predicted Score: {predicted_score[0][0]:.2f}")
# Out:
# I0000 00:00:1736688063.098269 7938281 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2 Pro
# W0000 00:00:1736688063.198559 8365498 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1736688063.212584 8365502 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Predicted Score: 0.22

# %%
def classify_score(prediction):
    """Classify the prediction into 0, 0.5, or 1 based on thresholds."""
    if prediction >= 0.85:
        return 1.0
    elif prediction >= 0.70:
        return 0.5
    else:
        return 0.0

# %%
# Predict the score for the new video
predicted_score = model.predict(features)
print(f"Predicted Score (Regression): {predicted_score[0][0]:.2f}")

# Classify the score
classified_score = classify_score(predicted_score[0][0])
print(f"Classified Score: {classified_score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Predicted Score (Regression): 0.73
# Classified Score: 0.5
