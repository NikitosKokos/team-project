# %%
import cv2
import os

# Paths
video_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/videos"
frames_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/frames"

# Ensure output directory exists
os.makedirs(frames_dir, exist_ok=True)

def extract_frames(video_path, output_dir, interval=1):
    """
    Extract frames from a video at a given interval (default: every 1 frame).
    """
    cap = cv2.VideoCapture(video_path)
    count = 0
    frame_count = 0
    video_name = os.path.basename(video_path).rsplit('.', 1)[0]  # Get the video name without extension

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Save every 'interval' frame
        if count % interval == 0:
            frame_path = os.path.join(output_dir, f"{video_name}_frame{frame_count}.jpg")
            cv2.imwrite(frame_path, frame)
            frame_count += 1

        count += 1

    cap.release()

# Process all videos
for video_file in os.listdir(video_dir):
    # Check if the filename ends with ".mp4" and starts with a valid number
    if video_file.endswith(".mp4"):
        try:
            # Split by '_' and attempt to convert the first part to float
            prefix = video_file.split('_')[0]
            float(prefix)  # This ensures it works for values like '0.5', '1', or '0'
            
            # Proceed with frame extraction
            video_path = os.path.join(video_dir, video_file)
            video_frames_dir = os.path.join(frames_dir, video_file.rsplit('.', 1)[0])  # Use full name
            os.makedirs(video_frames_dir, exist_ok=True)
            extract_frames(video_path, video_frames_dir)
            print(f"Frames extracted for {video_file}")
        except ValueError:
            print(f"Skipping file with invalid prefix: {video_file}")

print("Frame extraction completed!")
# Out:
# Frames extracted for 1_user2.mp4
# Frames extracted for 1_user14.mp4
# Frames extracted for 1_user1.mp4
# Frames extracted for 1_user5.mp4
# Frames extracted for 1_user10.mp4
# Frames extracted for 1_user6.mp4
# Frames extracted for 0_user22.mp4
# Frames extracted for 0_user4.mp4
# Frames extracted for 0_user21.mp4
# Frames extracted for 0_user12.mp4
# Frames extracted for 0_user8.mp4
# Frames extracted for 0_user13.mp4
# Frames extracted for 1_user23.mp4
# Frames extracted for 0.5_user3.mp4
# Frames extracted for 1_user9.mp4
# Frames extracted for 1_user20.mp4
# Frame extraction completed!

# %%
import cv2
import os
import mediapipe as mp
import json

# Paths
frames_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/frames"
keypoints_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/keypoints"

# Ensure output directory exists
os.makedirs(keypoints_dir, exist_ok=True)

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False)

def extract_keypoints_for_sprinting(frame_path):
    """
    Extract keypoints relevant to sprinting on the balls of the feet.
    """
    image = cv2.imread(frame_path)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    result = pose.process(rgb_image)

    if result.pose_landmarks:
        keypoints = {
            "right_foot_index": {
                "x": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].x,
                "y": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].y,
                "z": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_FOOT_INDEX].z,
            },
            "right_heel": {
                "x": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].x,
                "y": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].y,
                "z": result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL].z,
            },
            "left_foot_index": {
                "x": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].x,
                "y": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].y,
                "z": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_FOOT_INDEX].z,
            },
            "left_heel": {
                "x": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].x,
                "y": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].y,
                "z": result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HEEL].z,
            },
        }
        return keypoints
    return None

def analyze_running_on_balls_of_feet(keypoints_sequence):
    """
    Analyze if the athlete is running on the balls of their feet.
    """
    ball_of_foot_positions = []

    for keypoints in keypoints_sequence:
        right_foot = keypoints["right_foot_index"]
        right_heel = keypoints["right_heel"]
        left_foot = keypoints["left_foot_index"]
        left_heel = keypoints["left_heel"]

        # Check if the ball of the foot is closer to the ground (lower y) than the heel
        right_ball_contact = right_foot["y"] < right_heel["y"]
        left_ball_contact = left_foot["y"] < left_heel["y"]

        ball_of_foot_positions.append(right_ball_contact and left_ball_contact)

    # Return True if running on the balls of feet is consistent across all frames
    return all(ball_of_foot_positions)

def process_sprint_frames(video_frames_dir, output_path):
    """
    Process all frames for a sprint video, detect running style, and save keypoints as JSON.
    """
    keypoints_data = []
    for frame_file in sorted(os.listdir(video_frames_dir)):
        frame_path = os.path.join(video_frames_dir, frame_file)
        keypoints = extract_keypoints_for_sprinting(frame_path)
        if keypoints:
            keypoints_data.append(keypoints)

    # Check for sprinting on balls of feet
    runs_on_balls_of_feet = analyze_running_on_balls_of_feet(keypoints_data)

    # Save keypoints and analysis to JSON
    output_data = {
        "keypoints": keypoints_data,
        "runs_on_balls_of_feet": runs_on_balls_of_feet,
    }
    with open(output_path, 'w') as f:
        json.dump(output_data, f, indent=4)

# Process frames for each video
for video_name in os.listdir(frames_dir):
    video_frames_dir = os.path.join(frames_dir, video_name)
    if os.path.isdir(video_frames_dir):
        output_path = os.path.join(keypoints_dir, f"{video_name}_keypoints.json")
        process_sprint_frames(video_frames_dir, output_path)
        print(f"Keypoints and running style analysis completed for {video_name}")

print("Processing completed!")
# Out:
# I0000 00:00:1737385743.256771 6534933 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M4 Pro
# W0000 00:00:1737385743.307806 6556899 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737385743.332572 6556908 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Keypoints and running style analysis completed for 0_user4
# Keypoints and running style analysis completed for 1_user14
# Keypoints and running style analysis completed for 1_user5
# Keypoints and running style analysis completed for 1_user2
# Keypoints and running style analysis completed for 1_user23
# Keypoints and running style analysis completed for 0_user21
# Keypoints and running style analysis completed for 0_user8
# Keypoints and running style analysis completed for 0.5_user3
# Keypoints and running style analysis completed for 1_user10
# Keypoints and running style analysis completed for 1_user1
# Keypoints and running style analysis completed for 0_user12
# Keypoints and running style analysis completed for 1_user6
# Keypoints and running style analysis completed for 0_user13
# Keypoints and running style analysis completed for 1_user20
# Keypoints and running style analysis completed for 0_user22
# Keypoints and running style analysis completed for 1_user9
# Processing completed!

# %%
import os
import torch
from transformers import CLIPProcessor, CLIPModel
from PIL import Image

# Paths
frames_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/frames"
clip_features_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/clip_features"
os.makedirs(clip_features_dir, exist_ok=True)

# Load CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

def extract_clip_features(video_frames_dir, output_path, batch_size=8):
    """
    Extract CLIP features for all frames in a video using batch processing.
    """
    frame_features = []
    frame_paths = sorted(os.listdir(video_frames_dir))
    images = []

    for i, frame_file in enumerate(frame_paths):
        try:
            frame_path = os.path.join(video_frames_dir, frame_file)
            image = Image.open(frame_path).convert("RGB")
            images.append(image)

            # Process batch
            if len(images) == batch_size or i == len(frame_paths) - 1:
                inputs = processor(images=images, return_tensors="pt", padding=True).to(device)
                with torch.no_grad():
                    image_features = model.get_image_features(**inputs).cpu().numpy()
                    frame_features.extend(image_features)
                images = []  # Clear batch to free memory
        except Exception as e:
            print(f"Error processing frame {frame_file}: {e}")
            continue

    # Save features
    torch.save(frame_features, output_path)

# Process all videos
for video_name in os.listdir(frames_dir):
    video_frames_dir = os.path.join(frames_dir, video_name)
    if os.path.isdir(video_frames_dir):
        output_path = os.path.join(clip_features_dir, f"{video_name}_clip.pt")
        extract_clip_features(video_frames_dir, output_path)
        print(f"CLIP features extracted for {video_name}")

print("CLIP feature extraction completed!")
# Out:
# CLIP features extracted for 0_user4
# CLIP features extracted for 1_user14
# CLIP features extracted for 1_user5
# CLIP features extracted for 1_user2
# CLIP features extracted for 1_user23
# CLIP features extracted for 0_user21
# CLIP features extracted for 0_user8
# CLIP features extracted for 0.5_user3
# CLIP features extracted for 1_user10
# CLIP features extracted for 1_user1
# CLIP features extracted for 0_user12
# CLIP features extracted for 1_user6
# CLIP features extracted for 0_user13
# CLIP features extracted for 1_user20
# CLIP features extracted for 0_user22
# CLIP features extracted for 1_user9
# CLIP feature extraction completed!

# %%
import json
import os
import torch
import numpy as np
import math

# Paths
keypoints_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/keypoints"
clip_features_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/clip_features"
combined_features_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/combined_features"

# Ensure output directory exists
os.makedirs(combined_features_dir, exist_ok=True)

# Function to calculate the angle between three points (a, b, c) where b is the vertex
def calculate_angle(a, b, c):
    ba = [a[0] - b[0], a[1] - b[1]]
    bc = [c[0] - b[0], c[1] - b[1]]
    
    dot_product = ba[0] * bc[0] + ba[1] * bc[1]
    magnitude_a = math.sqrt(ba[0] ** 2 + ba[1] ** 2)
    magnitude_b = math.sqrt(bc[0] ** 2 + bc[1] ** 2)
    
    cos_angle = dot_product / (magnitude_a * magnitude_b)
    angle = math.acos(cos_angle) * (180.0 / math.pi)
    
    return angle

# Detect if the runner is consistently running on the balls of the feet
def detect_running_on_balls_of_feet(keypoints_sequence):
    running_on_balls_detected = True

    for keypoints in keypoints_sequence[-5:]:
        try:
            left_foot = keypoints["left_foot_index"]
            left_heel = keypoints["left_heel"]  # Changed to 'left_heel'
            right_foot = keypoints["right_foot_index"]
            right_heel = keypoints["right_heel"]  # Changed to 'right_heel'

            # Ensure the foot is above the heel in y-coordinate for running on balls of feet
            if not (left_foot["y"] < left_heel["y"] and right_foot["y"] < right_heel["y"]):
                running_on_balls_detected = False
                break
        except KeyError as e:
            print(f"KeyError: Missing key {e} in the keypoints data")
            running_on_balls_detected = False
            break

    return running_on_balls_detected

# Combine pose-based features and CLIP embeddings for each video
def combine_features(video_name, pose_path, clip_path, output_path):
    with open(pose_path, 'r') as f:
        keypoints_data = json.load(f)["keypoints"]

    # Detect if running on the balls of the feet during the last 5 steps
    running_on_balls = detect_running_on_balls_of_feet(keypoints_data)

    # Load CLIP embeddings
    clip_data = torch.load(clip_path)

    # Combine features for each frame
    combined_data = []
    for i, clip_frame in enumerate(clip_data):
        pose_features = {
            "running_on_balls_of_feet": 1 if running_on_balls else 0,  # Binary flag for running on balls of feet
        }
        
        # Get the keypoints from the pose data for this frame
        pose_keypoints = keypoints_data[i] if i < len(keypoints_data) else {}
        
        # Extract more features (e.g., foot positions)
        left_foot = pose_keypoints.get("left_foot_index", {"x": 0, "y": 0})
        right_foot = pose_keypoints.get("right_foot_index", {"x": 0, "y": 0})
        
        # Add additional pose features like foot position or other relevant metrics
        foot_distance = np.linalg.norm([left_foot["x"] - right_foot["x"], left_foot["y"] - right_foot["y"]])

        # Add this additional feature to the pose_features dictionary
        pose_features["foot_distance"] = foot_distance

        # Combine pose-based features with CLIP frame features
        combined_frame = np.concatenate([clip_frame, list(pose_features.values())])
        combined_data.append(combined_frame)

    # Save combined features
    torch.save(combined_data, output_path)

# Process all videos and combine features
for video_name in os.listdir(keypoints_dir):
    if video_name.endswith("_keypoints.json"):
        video_name_base = video_name.replace("_keypoints.json", "")
        pose_path = os.path.join(keypoints_dir, video_name)
        clip_path = os.path.join(clip_features_dir, f"{video_name_base}_clip.pt")
        output_path = os.path.join(combined_features_dir, f"{video_name_base}_combined.pt")

        if os.path.exists(clip_path):
            combine_features(video_name_base, pose_path, clip_path, output_path)
            print(f"Combined features saved for {video_name_base}")

print("Feature combination completed!")
# Out:
# Combined features saved for 0_user4
# Combined features saved for 1_user23
# Combined features saved for 0_user12
# Combined features saved for 1_user1
# Combined features saved for 1_user9
# Combined features saved for 0_user13
# Combined features saved for 1_user6
# Combined features saved for 0_user8
# Combined features saved for 1_user20
# Combined features saved for 1_user2
# Combined features saved for 1_user5
# Combined features saved for 0.5_user3
# Combined features saved for 1_user14
# Combined features saved for 0_user22
# Combined features saved for 1_user10
# Combined features saved for 0_user21
# Feature combination completed!
# /var/folders/fb/p7zywq8d7351kf4l4fwh2dmw0000gn/T/ipykernel_39571/3175453114.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   clip_data = torch.load(clip_path)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os

# Paths
combined_features_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/combined_features"

# Hyperparameters
sequence_length = 20  # Adjust as needed (still remains as sequence length)
batch_size = 16       # Adjust as needed

# Ensure input size is always 515
input_size = 515

class AthleticsDataset(Dataset):
    def __init__(self, combined_features_dir, sequence_length, input_size):
        """
        Handles loading and processing of combined features for athletics data.
        Ensures input size is always 515.
        """
        self.data = []
        self.labels = []
        self.sequence_length = sequence_length
        self.input_size = input_size

        for file in os.listdir(combined_features_dir):
            if file.endswith("_combined.pt"):
                # Load combined features
                video_features = torch.tensor(torch.load(os.path.join(combined_features_dir, file)), dtype=torch.float32)

                # Truncate or pad sequences to the desired length
                if video_features.shape[0] >= self.sequence_length:
                    video_features = video_features[:self.sequence_length]
                else:
                    padding = torch.zeros((self.sequence_length - video_features.shape[0], video_features.shape[1]))
                    video_features = torch.cat((video_features, padding), dim=0)

                # Ensure features match the input size (515)
                if video_features.shape[1] != self.input_size:
                    padding = torch.zeros((video_features.shape[0], self.input_size - video_features.shape[1]))
                    video_features = torch.cat((video_features, padding), dim=1)
                self.data.append(video_features)

                # Extract label from filename
                label = float(file.split("_")[0])  # Extract label from file name
                self.labels.append(label)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Initialize dataset and DataLoader
def get_data_loaders(combined_features_dir, sequence_length, batch_size, input_size, train_split=0.8):
    dataset = AthleticsDataset(combined_features_dir, sequence_length, input_size)
    train_size = int(train_split * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, input_size  # Return loaders and input size

# Create DataLoaders
train_loader, val_loader, input_size = get_data_loaders(combined_features_dir, sequence_length, batch_size, input_size)

print(f"DataLoaders created. Input size: {input_size}")
# Out:
# DataLoaders created. Input size: 515
# /var/folders/fb/p7zywq8d7351kf4l4fwh2dmw0000gn/T/ipykernel_39571/2609585906.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   video_features = torch.tensor(torch.load(os.path.join(combined_features_dir, file)), dtype=torch.float32)

# %%
import torch.nn as nn

class TemporalModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        """
        LSTM-based model for sequence prediction.
        """
        super(TemporalModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)  # Use the final hidden state
        output = self.fc(hidden[-1])  # Fully connected output
        return output

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import itertools
import os

# Paths
combined_features_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/combined_features"

# Dataset and DataLoader
class AthleticsDataset(torch.utils.data.Dataset):
    def __init__(self, combined_features_dir, sequence_length):
        self.data = []
        self.labels = []
        self.sequence_length = sequence_length

        for file in os.listdir(combined_features_dir):
            if file.endswith("_combined.pt"):
                video_features = torch.tensor(torch.load(os.path.join(combined_features_dir, file)), dtype=torch.float32)

                if video_features.shape[0] >= self.sequence_length:
                    video_features = video_features[:self.sequence_length]
                else:
                    padding = torch.zeros((self.sequence_length - video_features.shape[0], video_features.shape[1]))
                    video_features = torch.cat((video_features, padding), dim=0)

                self.data.append(video_features)
                label = float(file.split("_")[0])  # Extract label from file name
                self.labels.append(label)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

def get_data_loaders(combined_features_dir, sequence_length, batch_size, train_split=0.8):
    dataset = AthleticsDataset(combined_features_dir, sequence_length)
    train_size = int(train_split * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, dataset[0][0].shape[1]

# Define LSTM model
class TemporalModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout):
        super(TemporalModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        output = self.fc(hidden[-1])
        return output

# Training function with early stopping
def train_model(model, train_loader, val_loader, criterion, optimizer, device, num_epochs=500, patience=100):
    best_val_loss = float("inf")
    patience_counter = 0
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for features, labels in train_loader:
            features, labels = features.to(device), torch.tensor(labels, dtype=torch.float32).to(device)

            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs.squeeze(), labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), torch.tensor(labels, dtype=torch.float32).to(device)
                outputs = model(features)
                loss = criterion(outputs.squeeze(), labels)
                val_loss += loss.item()

        train_loss /= len(train_loader)
        val_loss /= len(val_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        # # Early stopping logic with 100 epochs patience
        # if val_loss < best_val_loss:
        #     best_val_loss = val_loss
        #     patience_counter = 0
        # else:
        #     patience_counter += 1

        # if patience_counter >= patience:
        #     print(f"Early stopping triggered after {patience} epochs without improvement!")
        #     break

    return best_val_loss


# Hyperparameter grid search
# def hyperparameter_search():
    # Hyperparameter grid
    hidden_sizes = [32, 64, 128]
    num_layers = [1, 2, 3]
    learning_rates = [0.001, 0.005, 0.0001, 0.0005]
    dropouts = [0.0, 0.2, 0.3]

    # Initialize variables to track the best model
    best_val_loss = float("inf")
    best_params = None
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # Prepare data
    train_loader, val_loader, input_size = get_data_loaders(combined_features_dir, sequence_length=20, batch_size=8)

    # Iterate over all combinations of hyperparameters
    for hidden_size, num_layer, learning_rate, dropout in itertools.product(hidden_sizes, num_layers, learning_rates, dropouts):
        print(f"Testing configuration: Hidden Size={hidden_size}, Num Layers={num_layer}, LR={learning_rate}, Dropout={dropout}")
        
        # Initialize model, criterion, and optimizer
        model = TemporalModel(input_size=input_size, hidden_size=hidden_size, num_layers=num_layer, output_size=1, dropout=dropout).to(device)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        # Train the model
        val_loss = train_model(model, train_loader, val_loader, criterion, optimizer, device)

        # Update best model if this configuration is better
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_params = {
                "hidden_size": hidden_size,
                "num_layers": num_layer,
                "learning_rate": learning_rate,
                "dropout": dropout,
            }

    print(f"Best Configuration: {best_params}, Validation Loss: {best_val_loss:.4f}")
    return best_params

# Run hyperparameter search
# best_params = hyperparameter_search()

# %%
# Train the final model with the best configuration
final_hidden_size = 128
final_num_layers = 1
final_learning_rate = 0.0012
final_dropout = 0.45

# Prepare DataLoaders (use full dataset for training)
train_loader, val_loader, input_size = get_data_loaders(combined_features_dir, sequence_length=20, batch_size=32)
print(f"Input size for the model: {input_size}")

# Initialize final model
device = "cuda" if torch.cuda.is_available() else "cpu"
final_model = TemporalModel(input_size=input_size, hidden_size=final_hidden_size, num_layers=final_num_layers, output_size=1, dropout=final_dropout).to(device)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(final_model.parameters(), lr=final_learning_rate)

# Train final model
final_val_loss = train_model(final_model, train_loader, val_loader, criterion, optimizer, device, num_epochs=1000, patience=100)
print(f"Final model trained. Validation Loss: {final_val_loss:.4f}")
# Out:
# /var/folders/fb/p7zywq8d7351kf4l4fwh2dmw0000gn/T/ipykernel_39571/3295563233.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   video_features = torch.tensor(torch.load(os.path.join(combined_features_dir, file)), dtype=torch.float32)
# /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.45 and num_layers=1
#   warnings.warn(
# /var/folders/fb/p7zywq8d7351kf4l4fwh2dmw0000gn/T/ipykernel_39571/3295563233.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   features, labels = features.to(device), torch.tensor(labels, dtype=torch.float32).to(device)
# /var/folders/fb/p7zywq8d7351kf4l4fwh2dmw0000gn/T/ipykernel_39571/3295563233.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   features, labels = features.to(device), torch.tensor(labels, dtype=torch.float32).to(device)
# Input size for the model: 514
# Epoch [1/1000], Train Loss: 0.5693, Val Loss: 0.2681
# Epoch [2/1000], Train Loss: 0.2215, Val Loss: 0.4665
# Epoch [3/1000], Train Loss: 0.2445, Val Loss: 0.4893
# Epoch [4/1000], Train Loss: 0.2168, Val Loss: 0.4045
# Epoch [5/1000], Train Loss: 0.1379, Val Loss: 0.3135
# Epoch [6/1000], Train Loss: 0.0817, Val Loss: 0.2547
# Epoch [7/1000], Train Loss: 0.0642, Val Loss: 0.2273
# Epoch [8/1000], Train Loss: 0.0665, Val Loss: 0.2185
# Epoch [9/1000], Train Loss: 0.0652, Val Loss: 0.2203
# Epoch [10/1000], Train Loss: 0.0511, Val Loss: 0.2326
# Epoch [11/1000], Train Loss: 0.0304, Val Loss: 0.2590
# Epoch [12/1000], Train Loss: 0.0147, Val Loss: 0.2989
# Epoch [13/1000], Train Loss: 0.0115, Val Loss: 0.3415
# Epoch [14/1000], Train Loss: 0.0186, Val Loss: 0.3680
# Epoch [15/1000], Train Loss: 0.0255, Val Loss: 0.3673
# Epoch [16/1000], Train Loss: 0.0242, Val Loss: 0.3441
# Epoch [17/1000], Train Loss: 0.0163, Val Loss: 0.3115
# Epoch [18/1000], Train Loss: 0.0082, Val Loss: 0.2811
# Epoch [19/1000], Train Loss: 0.0045, Val Loss: 0.2592
# Epoch [20/1000], Train Loss: 0.0052, Val Loss: 0.2468
# Epoch [21/1000], Train Loss: 0.0076, Val Loss: 0.2427
# Epoch [22/1000], Train Loss: 0.0087, Val Loss: 0.2455
# Epoch [23/1000], Train Loss: 0.0075, Val Loss: 0.2543
# Epoch [24/1000], Train Loss: 0.0049, Val Loss: 0.2679
# Epoch [25/1000], Train Loss: 0.0024, Val Loss: 0.2845
# Epoch [26/1000], Train Loss: 0.0013, Val Loss: 0.3016
# Epoch [27/1000], Train Loss: 0.0017, Val Loss: 0.3160
# Epoch [28/1000], Train Loss: 0.0030, Val Loss: 0.3253
# Epoch [29/1000], Train Loss: 0.0042, Val Loss: 0.3282
# Epoch [30/1000], Train Loss: 0.0044, Val Loss: 0.3251
# Epoch [31/1000], Train Loss: 0.0037, Val Loss: 0.3175
# Epoch [32/1000], Train Loss: 0.0025, Val Loss: 0.3076
# Epoch [33/1000], Train Loss: 0.0015, Val Loss: 0.2976
# Epoch [34/1000], Train Loss: 0.0010, Val Loss: 0.2891
# Epoch [35/1000], Train Loss: 0.0011, Val Loss: 0.2831
# Epoch [36/1000], Train Loss: 0.0015, Val Loss: 0.2802
# Epoch [37/1000], Train Loss: 0.0018, Val Loss: 0.2805
# Epoch [38/1000], Train Loss: 0.0017, Val Loss: 0.2836
# Epoch [39/1000], Train Loss: 0.0013, Val Loss: 0.2892
# Epoch [40/1000], Train Loss: 0.0008, Val Loss: 0.2962
# Epoch [41/1000], Train Loss: 0.0005, Val Loss: 0.3037
# Epoch [42/1000], Train Loss: 0.0004, Val Loss: 0.3104
# Epoch [43/1000], Train Loss: 0.0005, Val Loss: 0.3150
# Epoch [44/1000], Train Loss: 0.0007, Val Loss: 0.3170
# Epoch [45/1000], Train Loss: 0.0008, Val Loss: 0.3159
# Epoch [46/1000], Train Loss: 0.0007, Val Loss: 0.3124
# Epoch [47/1000], Train Loss: 0.0005, Val Loss: 0.3073
# Epoch [48/1000], Train Loss: 0.0002, Val Loss: 0.3016
# Epoch [49/1000], Train Loss: 0.0001, Val Loss: 0.2964
# Epoch [50/1000], Train Loss: 0.0001, Val Loss: 0.2924
# Epoch [51/1000], Train Loss: 0.0002, Val Loss: 0.2902
# Epoch [52/1000], Train Loss: 0.0003, Val Loss: 0.2897
# Epoch [53/1000], Train Loss: 0.0003, Val Loss: 0.2910
# Epoch [54/1000], Train Loss: 0.0003, Val Loss: 0.2937
# Epoch [55/1000], Train Loss: 0.0002, Val Loss: 0.2972
# Epoch [56/1000], Train Loss: 0.0001, Val Loss: 0.3009
# Epoch [57/1000], Train Loss: 0.0001, Val Loss: 0.3041
# Epoch [58/1000], Train Loss: 0.0002, Val Loss: 0.3063
# Epoch [59/1000], Train Loss: 0.0002, Val Loss: 0.3070
# Epoch [60/1000], Train Loss: 0.0002, Val Loss: 0.3064
# Epoch [61/1000], Train Loss: 0.0002, Val Loss: 0.3047
# Epoch [62/1000], Train Loss: 0.0001, Val Loss: 0.3022
# Epoch [63/1000], Train Loss: 0.0000, Val Loss: 0.2997
# Epoch [64/1000], Train Loss: 0.0000, Val Loss: 0.2975
# Epoch [65/1000], Train Loss: 0.0000, Val Loss: 0.2961
# Epoch [66/1000], Train Loss: 0.0001, Val Loss: 0.2956
# Epoch [67/1000], Train Loss: 0.0001, Val Loss: 0.2961
# Epoch [68/1000], Train Loss: 0.0001, Val Loss: 0.2974
# Epoch [69/1000], Train Loss: 0.0000, Val Loss: 0.2992
# Epoch [70/1000], Train Loss: 0.0000, Val Loss: 0.3011
# Epoch [71/1000], Train Loss: 0.0000, Val Loss: 0.3027
# Epoch [72/1000], Train Loss: 0.0000, Val Loss: 0.3038
# Epoch [73/1000], Train Loss: 0.0000, Val Loss: 0.3041
# Epoch [74/1000], Train Loss: 0.0000, Val Loss: 0.3037
# Epoch [75/1000], Train Loss: 0.0000, Val Loss: 0.3026
# Epoch [76/1000], Train Loss: 0.0000, Val Loss: 0.3012
# Epoch [77/1000], Train Loss: 0.0000, Val Loss: 0.2998
# Epoch [78/1000], Train Loss: 0.0000, Val Loss: 0.2987
# Epoch [79/1000], Train Loss: 0.0000, Val Loss: 0.2980
# Epoch [80/1000], Train Loss: 0.0000, Val Loss: 0.2978
# Epoch [81/1000], Train Loss: 0.0000, Val Loss: 0.2982
# Epoch [82/1000], Train Loss: 0.0000, Val Loss: 0.2990
# Epoch [83/1000], Train Loss: 0.0000, Val Loss: 0.3000
# Epoch [84/1000], Train Loss: 0.0000, Val Loss: 0.3010
# Epoch [85/1000], Train Loss: 0.0000, Val Loss: 0.3017
# Epoch [86/1000], Train Loss: 0.0000, Val Loss: 0.3022
# Epoch [87/1000], Train Loss: 0.0000, Val Loss: 0.3022
# Epoch [88/1000], Train Loss: 0.0000, Val Loss: 0.3018
# Epoch [89/1000], Train Loss: 0.0000, Val Loss: 0.3012
# Epoch [90/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [91/1000], Train Loss: 0.0000, Val Loss: 0.2999
# Epoch [92/1000], Train Loss: 0.0000, Val Loss: 0.2995
# Epoch [93/1000], Train Loss: 0.0000, Val Loss: 0.2994
# Epoch [94/1000], Train Loss: 0.0000, Val Loss: 0.2997
# Epoch [95/1000], Train Loss: 0.0000, Val Loss: 0.3001
# Epoch [96/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [97/1000], Train Loss: 0.0000, Val Loss: 0.3011
# Epoch [98/1000], Train Loss: 0.0000, Val Loss: 0.3015
# Epoch [99/1000], Train Loss: 0.0000, Val Loss: 0.3017
# Epoch [100/1000], Train Loss: 0.0000, Val Loss: 0.3016
# Epoch [101/1000], Train Loss: 0.0000, Val Loss: 0.3013
# Epoch [102/1000], Train Loss: 0.0000, Val Loss: 0.3009
# Epoch [103/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [104/1000], Train Loss: 0.0000, Val Loss: 0.3002
# Epoch [105/1000], Train Loss: 0.0000, Val Loss: 0.3000
# Epoch [106/1000], Train Loss: 0.0000, Val Loss: 0.3000
# Epoch [107/1000], Train Loss: 0.0000, Val Loss: 0.3001
# Epoch [108/1000], Train Loss: 0.0000, Val Loss: 0.3004
# Epoch [109/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [110/1000], Train Loss: 0.0000, Val Loss: 0.3009
# Epoch [111/1000], Train Loss: 0.0000, Val Loss: 0.3011
# Epoch [112/1000], Train Loss: 0.0000, Val Loss: 0.3011
# Epoch [113/1000], Train Loss: 0.0000, Val Loss: 0.3010
# Epoch [114/1000], Train Loss: 0.0000, Val Loss: 0.3008
# Epoch [115/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [116/1000], Train Loss: 0.0000, Val Loss: 0.3004
# Epoch [117/1000], Train Loss: 0.0000, Val Loss: 0.3003
# Epoch [118/1000], Train Loss: 0.0000, Val Loss: 0.3003
# Epoch [119/1000], Train Loss: 0.0000, Val Loss: 0.3003
# Epoch [120/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [121/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [122/1000], Train Loss: 0.0000, Val Loss: 0.3008
# Epoch [123/1000], Train Loss: 0.0000, Val Loss: 0.3009
# Epoch [124/1000], Train Loss: 0.0000, Val Loss: 0.3009
# Epoch [125/1000], Train Loss: 0.0000, Val Loss: 0.3008
# Epoch [126/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [127/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [128/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [129/1000], Train Loss: 0.0000, Val Loss: 0.3004
# Epoch [130/1000], Train Loss: 0.0000, Val Loss: 0.3004
# Epoch [131/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [132/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [133/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [134/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [135/1000], Train Loss: 0.0000, Val Loss: 0.3008
# Epoch [136/1000], Train Loss: 0.0000, Val Loss: 0.3008
# Epoch [137/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [138/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [139/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [140/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [141/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [142/1000], Train Loss: 0.0000, Val Loss: 0.3005
# Epoch [143/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [144/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [145/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [146/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [147/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [148/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [149/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [150/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [151/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [152/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [153/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [154/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [155/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [156/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [157/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [158/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [159/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [160/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [161/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [162/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [163/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [164/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [165/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [166/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [167/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [168/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [169/1000], Train Loss: 0.0000, Val Loss: 0.3007
# Epoch [170/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [171/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [172/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [173/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [174/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [175/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [176/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [177/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [178/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [179/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [180/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [181/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [182/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [183/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [184/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [185/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [186/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [187/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [188/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [189/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [190/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [191/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [192/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [193/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [194/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [195/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [196/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [197/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [198/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [199/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [200/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [201/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [202/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [203/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [204/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [205/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [206/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [207/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [208/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [209/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [210/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [211/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [212/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [213/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [214/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [215/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [216/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [217/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [218/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [219/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [220/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [221/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [222/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [223/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [224/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [225/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [226/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [227/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [228/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [229/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [230/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [231/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [232/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [233/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [234/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [235/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [236/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [237/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [238/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [239/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [240/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [241/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [242/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [243/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [244/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [245/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [246/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [247/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [248/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [249/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [250/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [251/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [252/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [253/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [254/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [255/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [256/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [257/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [258/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [259/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [260/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [261/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [262/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [263/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [264/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [265/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [266/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [267/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [268/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [269/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [270/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [271/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [272/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [273/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [274/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [275/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [276/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [277/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [278/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [279/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [280/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [281/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [282/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [283/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [284/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [285/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [286/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [287/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [288/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [289/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [290/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [291/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [292/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [293/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [294/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [295/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [296/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [297/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [298/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [299/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [300/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [301/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [302/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [303/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [304/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [305/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [306/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [307/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [308/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [309/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [310/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [311/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [312/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [313/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [314/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [315/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [316/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [317/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [318/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [319/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [320/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [321/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [322/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [323/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [324/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [325/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [326/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [327/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [328/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [329/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [330/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [331/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [332/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [333/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [334/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [335/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [336/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [337/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [338/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [339/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [340/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [341/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [342/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [343/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [344/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [345/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [346/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [347/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [348/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [349/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [350/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [351/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [352/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [353/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [354/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [355/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [356/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [357/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [358/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [359/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [360/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [361/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [362/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [363/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [364/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [365/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [366/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [367/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [368/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [369/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [370/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [371/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [372/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [373/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [374/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [375/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [376/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [377/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [378/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [379/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [380/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [381/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [382/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [383/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [384/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [385/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [386/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [387/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [388/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [389/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [390/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [391/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [392/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [393/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [394/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [395/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [396/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [397/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [398/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [399/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [400/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [401/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [402/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [403/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [404/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [405/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [406/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [407/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [408/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [409/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [410/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [411/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [412/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [413/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [414/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [415/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [416/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [417/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [418/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [419/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [420/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [421/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [422/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [423/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [424/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [425/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [426/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [427/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [428/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [429/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [430/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [431/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [432/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [433/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [434/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [435/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [436/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [437/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [438/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [439/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [440/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [441/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [442/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [443/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [444/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [445/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [446/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [447/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [448/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [449/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [450/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [451/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [452/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [453/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [454/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [455/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [456/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [457/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [458/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [459/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [460/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [461/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [462/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [463/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [464/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [465/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [466/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [467/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [468/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [469/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [470/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [471/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [472/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [473/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [474/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [475/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [476/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [477/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [478/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [479/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [480/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [481/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [482/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [483/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [484/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [485/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [486/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [487/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [488/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [489/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [490/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [491/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [492/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [493/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [494/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [495/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [496/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [497/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [498/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [499/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [500/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [501/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [502/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [503/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [504/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [505/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [506/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [507/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [508/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [509/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [510/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [511/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [512/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [513/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [514/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [515/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [516/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [517/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [518/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [519/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [520/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [521/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [522/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [523/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [524/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [525/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [526/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [527/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [528/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [529/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [530/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [531/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [532/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [533/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [534/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [535/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [536/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [537/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [538/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [539/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [540/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [541/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [542/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [543/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [544/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [545/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [546/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [547/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [548/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [549/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [550/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [551/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [552/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [553/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [554/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [555/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [556/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [557/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [558/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [559/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [560/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [561/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [562/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [563/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [564/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [565/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [566/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [567/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [568/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [569/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [570/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [571/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [572/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [573/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [574/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [575/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [576/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [577/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [578/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [579/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [580/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [581/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [582/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [583/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [584/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [585/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [586/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [587/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [588/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [589/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [590/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [591/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [592/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [593/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [594/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [595/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [596/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [597/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [598/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [599/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [600/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [601/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [602/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [603/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [604/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [605/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [606/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [607/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [608/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [609/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [610/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [611/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [612/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [613/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [614/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [615/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [616/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [617/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [618/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [619/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [620/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [621/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [622/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [623/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [624/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [625/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [626/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [627/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [628/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [629/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [630/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [631/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [632/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [633/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [634/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [635/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [636/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [637/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [638/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [639/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [640/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [641/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [642/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [643/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [644/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [645/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [646/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [647/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [648/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [649/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [650/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [651/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [652/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [653/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [654/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [655/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [656/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [657/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [658/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [659/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [660/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [661/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [662/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [663/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [664/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [665/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [666/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [667/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [668/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [669/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [670/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [671/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [672/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [673/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [674/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [675/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [676/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [677/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [678/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [679/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [680/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [681/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [682/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [683/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [684/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [685/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [686/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [687/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [688/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [689/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [690/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [691/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [692/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [693/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [694/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [695/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [696/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [697/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [698/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [699/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [700/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [701/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [702/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [703/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [704/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [705/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [706/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [707/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [708/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [709/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [710/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [711/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [712/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [713/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [714/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [715/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [716/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [717/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [718/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [719/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [720/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [721/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [722/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [723/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [724/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [725/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [726/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [727/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [728/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [729/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [730/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [731/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [732/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [733/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [734/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [735/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [736/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [737/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [738/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [739/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [740/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [741/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [742/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [743/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [744/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [745/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [746/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [747/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [748/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [749/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [750/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [751/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [752/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [753/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [754/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [755/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [756/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [757/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [758/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [759/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [760/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [761/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [762/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [763/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [764/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [765/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [766/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [767/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [768/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [769/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [770/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [771/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [772/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [773/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [774/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [775/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [776/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [777/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [778/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [779/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [780/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [781/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [782/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [783/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [784/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [785/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [786/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [787/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [788/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [789/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [790/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [791/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [792/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [793/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [794/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [795/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [796/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [797/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [798/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [799/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [800/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [801/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [802/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [803/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [804/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [805/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [806/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [807/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [808/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [809/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [810/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [811/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [812/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [813/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [814/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [815/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [816/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [817/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [818/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [819/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [820/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [821/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [822/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [823/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [824/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [825/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [826/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [827/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [828/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [829/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [830/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [831/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [832/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [833/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [834/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [835/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [836/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [837/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [838/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [839/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [840/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [841/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [842/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [843/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [844/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [845/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [846/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [847/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [848/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [849/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [850/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [851/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [852/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [853/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [854/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [855/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [856/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [857/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [858/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [859/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [860/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [861/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [862/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [863/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [864/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [865/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [866/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [867/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [868/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [869/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [870/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [871/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [872/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [873/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [874/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [875/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [876/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [877/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [878/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [879/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [880/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [881/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [882/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [883/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [884/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [885/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [886/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [887/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [888/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [889/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [890/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [891/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [892/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [893/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [894/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [895/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [896/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [897/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [898/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [899/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [900/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [901/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [902/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [903/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [904/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [905/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [906/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [907/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [908/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [909/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [910/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [911/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [912/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [913/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [914/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [915/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [916/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [917/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [918/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [919/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [920/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [921/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [922/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [923/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [924/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [925/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [926/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [927/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [928/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [929/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [930/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [931/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [932/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [933/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [934/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [935/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [936/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [937/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [938/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [939/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [940/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [941/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [942/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [943/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [944/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [945/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [946/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [947/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [948/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [949/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [950/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [951/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [952/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [953/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [954/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [955/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [956/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [957/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [958/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [959/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [960/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [961/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [962/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [963/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [964/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [965/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [966/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [967/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [968/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [969/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [970/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [971/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [972/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [973/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [974/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [975/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [976/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [977/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [978/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [979/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [980/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [981/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [982/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [983/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [984/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [985/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [986/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [987/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [988/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [989/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [990/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [991/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [992/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [993/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [994/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [995/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [996/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [997/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [998/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [999/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Epoch [1000/1000], Train Loss: 0.0000, Val Loss: 0.3006
# Final model trained. Validation Loss: inf

# %%
import matplotlib.pyplot as plt

def evaluate_and_collect_predictions(model, data_loader, device):
    """
    Evaluate the model on the provided DataLoader and collect true vs. predicted values.
    """
    model.eval()
    true_labels = []
    predicted_labels = []

    with torch.no_grad():
        for features, labels in data_loader:
            features = features.to(device)
            labels = labels.to(device)

            # Get model predictions
            outputs = model(features).squeeze()
            predicted_labels.extend(outputs.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    return true_labels, predicted_labels

# Use validation set for evaluation
true_labels, predicted_labels = evaluate_and_collect_predictions(final_model, val_loader, device)

# %%
import cv2
import os
import torch
from PIL import Image
import numpy as np
from transformers import CLIPProcessor, CLIPModel
import mediapipe as mp

# Paths for sprint technique
video_dir = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/videos"
sequence_length = 20  # Sequence length for LSTM

# Initialize CLIP and MediaPipe
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False)

# Ensure input size is always 513 for sprint technique
input_size = 514

# Process and Predict for each video
def process_and_predict(video_path, model, sequence_length):
    print(f"Processing video: {os.path.basename(video_path)}")
    
    # Step 1: Extract frames from video
    frames = []
    cap = cv2.VideoCapture(video_path)
    count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if count % 5 == 0:  # Extract frame every 5th frame
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(rgb_frame)
        count += 1
    cap.release()

    # Step 2: Extract pose keypoints using MediaPipe
    keypoints = []
    for frame in frames:
        result = pose.process(frame)
        if result.pose_landmarks:
            keypoints.append([
                {"x": lm.x, "y": lm.y, "z": lm.z, "visibility": lm.visibility}
                for lm in result.pose_landmarks.landmark
            ])
    
    # Step 3: Calculate stride scores for "Runs on the balls of the feet"
    stride_scores = []
    for i in range(1, len(keypoints)):
        prev_toe = keypoints[i - 1][32]  # Right toe
        curr_toe = keypoints[i][32]

        # Calculate vertical displacement of the toe (relative to ground contact)
        vertical_displacement = curr_toe['y'] - prev_toe['y']
        stride_scores.append(vertical_displacement > 0)  # True if lifting (on the ball of the foot)

    # Step 4: Extract CLIP embeddings for frames (semantic features)
    clip_embeddings = []
    for frame in frames:
        image = Image.fromarray(frame)
        inputs = clip_processor(images=image, return_tensors="pt").to(device)
        with torch.no_grad():
            embedding = clip_model.get_image_features(**inputs).cpu().numpy().flatten()
            clip_embeddings.append(embedding)

    # Step 5: Combine all features (CLIP and stride scores)
    combined_features = []
    for i, clip_embedding in enumerate(clip_embeddings):
        feature_vector = np.concatenate([
            clip_embedding,
            [stride_scores[i] if i < len(stride_scores) else 0]
        ])
        
        if len(feature_vector) > input_size:
            feature_vector = feature_vector[:input_size]  # Truncate if too long
        elif len(feature_vector) < input_size:
            padding = np.zeros(input_size - len(feature_vector))  # Pad with zeros if too short
            feature_vector = np.concatenate([feature_vector, padding])
        combined_features.append(feature_vector)
    
    # Convert to tensor
    combined_features = torch.tensor(combined_features, dtype=torch.float32)

    # Step 6: Truncate or pad sequences to the fixed sequence length
    if combined_features.shape[0] >= sequence_length:
        combined_features = combined_features[:sequence_length]
    else:
        padding = torch.zeros((sequence_length - combined_features.shape[0], combined_features.shape[1]))
        combined_features = torch.cat((combined_features, padding), dim=0)

    # Step 7: Predict using the model
    model.eval()
    with torch.no_grad():
        combined_features = combined_features.unsqueeze(0).to(device)  # Add batch dimension
        prediction = model(combined_features).squeeze().cpu().item()

    print(f"Prediction: {prediction:.4f}")
    return prediction


# Process all videos in the directory and predict
results = {}
for video_file in os.listdir(video_dir):
    if video_file.endswith(".mp4"):
        video_path = os.path.join(video_dir, video_file)
        prediction = process_and_predict(video_path, final_model, sequence_length)
        results[video_file] = prediction

# Print results
print("\nPrediction Results:")
for video, prediction in results.items():
    print(f"{video}: {prediction:.4f}")
# Out:
# I0000 00:00:1737386180.301748 6534933 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M4 Pro
# W0000 00:00:1737386180.360989 6569758 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737386180.390244 6569758 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Processing video: 1_user2.mp4
# Prediction: 0.9078
# Processing video: 1_user14.mp4
# Prediction: 0.9111
# Processing video: 1_user1.mp4
# Prediction: 0.9305
# Processing video: 1_user5.mp4
# Prediction: 0.0160
# Processing video: 1_user10.mp4
# Prediction: 0.6384
# Processing video: 1_user6.mp4
# Prediction: 0.8110
# Processing video: 0_user22.mp4
# Prediction: 0.3679
# Processing video: 0_user4.mp4
# Prediction: 0.2379
# Processing video: 0_user21.mp4
# Prediction: 0.0007
# Processing video: 0_user12.mp4
# Prediction: 0.2505
# Processing video: 0_user8.mp4
# Prediction: 0.0041
# Processing video: 0_user13.mp4
# Prediction: 0.7506
# Processing video: 1_user23.mp4
# Prediction: 0.9504
# Processing video: 0.5_user3.mp4
# Prediction: 0.4743
# Processing video: 1_user9.mp4
# Prediction: 0.0028
# Processing video: 1_user20.mp4
# Prediction: 0.5156
#
# Prediction Results:
# 1_user2.mp4: 0.9078
# 1_user14.mp4: 0.9111
# 1_user1.mp4: 0.9305
# 1_user5.mp4: 0.0160
# 1_user10.mp4: 0.6384
# 1_user6.mp4: 0.8110
# 0_user22.mp4: 0.3679
# 0_user4.mp4: 0.2379
# 0_user21.mp4: 0.0007
# 0_user12.mp4: 0.2505
# 0_user8.mp4: 0.0041
# 0_user13.mp4: 0.7506
# 1_user23.mp4: 0.9504
# 0.5_user3.mp4: 0.4743
# 1_user9.mp4: 0.0028
# 1_user20.mp4: 0.5156

# %%
torch.save(final_model.state_dict(), "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/sprint_technique/stages/stage1/stage1_sprint.pth")

# %% [markdown]
# ___

# %% [markdown]
# ## feedback generation

# %%
def process_video_with_metadata(video_path, model, sequence_length):
    """
    Process a video and return structured metadata with predictions and pose metrics.
    """
    print(f"Processing video: {os.path.basename(video_path)}")
    
    # Step 1: Extract frames
    frames = extract_frames(video_path)
    
    # Step 2: Extract keypoints
    keypoints = extract_keypoints(frames)

    # Step 3: Calculate pose-based features
    velocities, accelerations = calculate_velocity_and_acceleration(keypoints)
    stride_lengths = calculate_stride_length(keypoints)

    # Pose metrics
    pose_metrics = {
        "average_velocity": np.mean(velocities) if velocities else 0,
        "max_stride_length": np.max(stride_lengths) if stride_lengths else 0,
        "average_acceleration": np.mean(accelerations) if accelerations else 0
    }

    # Step 4: Extract CLIP features
    clip_embeddings = extract_clip_features(frames)

    # CLIP insights
    clip_summary = "High contextual alignment with accelerating motion."  # Placeholder for now

    # Step 5: Combine features
    combined_features = combine_features(clip_embeddings, velocities, accelerations, stride_lengths)

    # Step 6: Truncate or pad sequences
    if combined_features.shape[0] >= sequence_length:
        combined_features = combined_features[:sequence_length]
    else:
        padding = torch.zeros((sequence_length - combined_features.shape[0], combined_features.shape[1]))
        combined_features = torch.cat((combined_features, padding), dim=0)

    # Step 7: Predict using the model
    model.eval()
    with torch.no_grad():
        combined_features = combined_features.unsqueeze(0).to(device)  # Add batch dimension
        prediction = model(combined_features).squeeze().cpu().item()

    print(f"Prediction: {prediction:.4f}")

    # Return structured metadata
    return {
        "video_name": os.path.basename(video_path),
        "prediction": prediction,
        "pose_metrics": pose_metrics,
        "clip_features": {"embedding_summary": clip_summary}
    }

# %%
# from transformers import pipeline

# generator = pipeline("text2text-generation", model="google/flan-t5-base")
# result = generator("Explain the performance of an athlete based on metrics.", max_length=50)
# print(result[0]['generated_text'])


# def validate_metadata(metadata):
#     required_keys = {
#         'video_name': str,
#         'prediction': float,
#         'pose_metrics': dict,
#         'clip_features': dict,
#     }
#     pose_metrics_keys = ['average_velocity', 'max_stride_length', 'average_acceleration']
#     clip_features_keys = ['embedding_summary']

#     for key, expected_type in required_keys.items():
#         if key not in metadata or not isinstance(metadata[key], expected_type):
#             raise ValueError(f"Invalid or missing key: {key}, expected type: {expected_type}")
    
#     for key in pose_metrics_keys:
#         if key not in metadata['pose_metrics']:
#             raise ValueError(f"Missing pose metric: {key}")
    
#     for key in clip_features_keys:
#         if key not in metadata['clip_features']:
#             raise ValueError(f"Missing clip feature: {key}")

# def generate_justification(metadata, max_length=150, num_return_sequences=1):
#     validate_metadata(metadata)
    
#     # Dynamic prompt construction
#     metrics_prompt = []
#     for metric, value in metadata['pose_metrics'].items():
#         metrics_prompt.append(f"- {metric.replace('_', ' ').title()}: {value:.2f}")
#     metrics_text = "\n".join(metrics_prompt)

#     prompt = f"""
#     Analyze the performance for {metadata['video_name']}.
#     The predicted score is {metadata['prediction']:.2f}.
#     Key metrics:
#     {metrics_text}
#     - CLIP embedding summary: {metadata['clip_features']['embedding_summary']}
    
#     Based on these metrics, explain why the score is appropriate and provide constructive feedback for improvement.
#     """
#     print("Generated prompt:", prompt)  # Debugging log
#     result = generator(prompt, max_length=max_length, num_return_sequences=num_return_sequences)
#     return result[0]['generated_text']

# %%
# # Directory containing videos
# video_dir = "/Users/cezar/Desktop/Team Project/AI/distance_jump/stage1/videos"

# # Dictionary to store results
# results = {}

# for video_file in os.listdir(video_dir):
#     if video_file.endswith(".mp4"):
#         video_path = os.path.join(video_dir, video_file)
        
#         # Step 1: Process video and generate metadata
#         metadata = process_video_with_metadata(video_path, final_model, sequence_length=20)
        
#         # Step 2: Generate justification using Hugging Face model
#         justification = generate_justification(metadata)
#         metadata["justification"] = justification
        
#         # Store results
#         results[video_file] = metadata

# # Print results
# for video, data in results.items():
#     print(f"Video: {video}")
#     print(f"Prediction: {data['prediction']:.4f}")
#     print(f"Justification: {data['justification']}")
#     print("-" * 50)

# # Optional: Save results to JSON
# # import json
# # with open("video_predictions_with_justifications.json", "w") as f:
# #     json.dump(results, f, indent=4)
