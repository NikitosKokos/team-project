# %%
import cv2
import mediapipe as mp
import os
import json
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import json

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Function to check if the discus is released via the index finger
def is_discus_released(index_finger, wrist):
    """
    Determines if the discus is released via the index finger by analyzing 
    the relative position of the index finger and wrist.
    A release condition is met if the index finger extends ahead of the wrist 
    with minimal vertical displacement.
    """
    index_x, index_y = index_finger
    wrist_x, wrist_y = wrist

    # Discus release condition: index finger extends beyond wrist with minimal vertical movement
    return index_x > wrist_x and abs(index_y - wrist_y) < 0.01

# Paths for the discus throwing videos and keypoints storage
stage_path = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/disc_throwing/stages/stage5/videos"
keypoints_folder = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/disc_throwing/stages/stage5/keypoints"

# Ensure keypoints folder exists
os.makedirs(keypoints_folder, exist_ok=True)

for file in os.listdir(stage_path):
    if file.endswith(".mp4"):
        video_file_path = os.path.join(stage_path, file)
        cap = cv2.VideoCapture(video_file_path)

        keypoints_data = []  # Store keypoints for this video

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Convert frame to RGB for MediaPipe processing
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            result = pose.process(frame_rgb)

            if result.pose_landmarks:
                landmarks = result.pose_landmarks.landmark

                # Extract relevant keypoints for discus release analysis (right hand)
                right_index_finger = [landmarks[mp_pose.PoseLandmark.RIGHT_INDEX].x,
                                      landmarks[mp_pose.PoseLandmark.RIGHT_INDEX].y]
                right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST].x,
                               landmarks[mp_pose.PoseLandmark.RIGHT_WRIST].y]

                # Check if discus is released via index finger
                discus_released = is_discus_released(right_index_finger, right_wrist)

                # Store data for this frame with standard Python booleans and float conversion
                keypoints_data.append({
                    "frame": int(cap.get(cv2.CAP_PROP_POS_FRAMES)),
                    "discus_released": bool(discus_released),
                    "right_index_finger": [float(coord) for coord in right_index_finger],
                    "right_wrist": [float(coord) for coord in right_wrist]
                })

        # Release the video
        cap.release()

        # Save keypoints to the keypoints folder
        json_filename = os.path.splitext(file)[0] + "_keypoints.json"
        json_path = os.path.join(keypoints_folder, json_filename)
        with open(json_path, "w") as json_file:
            json.dump(keypoints_data, json_file, indent=4)

print("Discus release analysis complete! JSON files saved in 'keypoints' folder.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737673114.706591 12325729 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M4 Pro
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1737673114.762469 12371059 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737673114.772853 12371065 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737673114.785942 12371066 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Discus release analysis complete! JSON files saved in 'keypoints' folder.

# %%
import os
import json
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Path to the keypoints folder for discus release analysis
keypoints_folder = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/disc_throwing/stages/stage5/keypoints"

# Lists to store sequences and labels
sequences = []
labels = []

# Process keypoint JSON files
for file in os.listdir(keypoints_folder):
    if file.endswith("_keypoints.json"):
        file_path = os.path.join(keypoints_folder, file)
        
        with open(file_path, "r") as f:
            try:
                data = json.load(f)
            except json.JSONDecodeError:
                print(f"Error loading JSON from {file}")
                continue

        # Ensure the data is a list
        if isinstance(data, list):
            discus_release_data = [
                [int(frame.get("discus_released", 0))]  # Default to 0 if key is missing
                for frame in data if isinstance(frame, dict)
            ]
            sequences.append(discus_release_data)
        else:
            print(f"Unexpected format in {file}, skipping.")

        # Extract label from filename (assumes label is the first part of filename)
        try:
            label = float(file.split("_")[0])  # Modify if filename structure differs
            labels.append(label)
        except ValueError:
            print(f"Warning: Unable to extract label from {file}")
            continue

# Pad sequences to ensure uniform input shape
if sequences:
    max_len = max(len(seq) for seq in sequences)
    sequences = pad_sequences(sequences, maxlen=max_len, padding='post', dtype='float32')
    labels = np.array(labels)

    print(f"Loaded {len(sequences)} sequences with labels.")
else:
    print("No sequences found in the keypoints folder.")
# Out:
# Loaded 15 sequences with labels.

# %%
def augment_data(sequence):
    augmented_sequences = []

    # Original
    augmented_sequences.append(sequence)

    # Mirrored (flip angles horizontally)
    mirrored = -sequence
    augmented_sequences.append(mirrored)

    # Rotation (add a small angle offset)
    rotated = sequence + np.random.uniform(-10, 10, size=sequence.shape)
    augmented_sequences.append(rotated)

    # Noise (add random Gaussian noise)
    noisy = sequence + np.random.normal(0, 0.05, size=sequence.shape)
    augmented_sequences.append(noisy)

    # Scaled (adjust by a small percentage)
    scaled = sequence * np.random.uniform(0.9, 1.1)
    augmented_sequences.append(scaled)

    return augmented_sequences

augmented_sequences = []
augmented_labels = []

for seq, label in zip(sequences, labels):
    augmented = augment_data(seq)
    augmented_sequences.extend(augmented)
    augmented_labels.extend([label] * len(augmented))

augmented_sequences = np.array(augmented_sequences)
augmented_labels = np.array(augmented_labels)

print(f"Augmented dataset size: {len(augmented_sequences)}")
# Out:
# Augmented dataset size: 75

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Split the data
X_train, X_val, y_train, y_val = train_test_split(
    augmented_sequences, augmented_labels, test_size=4/17, random_state=42
)

# Debugging: Print shape before reshaping
print("Shape before reshaping - X_train:", np.array(X_train).shape)
print("Shape before reshaping - X_val:", np.array(X_val).shape)

# Dynamically infer number of features
num_features = np.array(X_train).shape[-1] if len(np.array(X_train).shape) > 2 else 1

# Ensure correct shape for LSTM input (samples, timesteps, features)
X_train = np.array(X_train).reshape((X_train.shape[0], X_train.shape[1], num_features))
X_val = np.array(X_val).reshape((X_val.shape[0], X_val.shape[1], num_features))

print(f"Training samples: {len(X_train)}, Validation samples: {len(X_val)}")
print(f"Final shape of X_train: {X_train.shape}")
print(f"Final shape of X_val: {X_val.shape}")
# Out:
# Shape before reshaping - X_train: (57, 33, 1)
# Shape before reshaping - X_val: (18, 33, 1)
# Training samples: 57, Validation samples: 18
# Final shape of X_train: (57, 33, 1)
# Final shape of X_val: (18, 33, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define enhanced LSTM model
model = Sequential([
    Bidirectional(LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_train.shape[1], 2))),
    Dropout(0.5),

    Bidirectional(LSTM(64, activation='tanh', return_sequences=True)),
    Dropout(0.4),

    Bidirectional(LSTM(32, activation='tanh', return_sequences=False)),
    Dropout(0.3),

    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)  # Output: Regression score
])

# Compile the model with a reduced learning rate for better convergence
model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse', metrics=['mae'])

print(model.summary())
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Train the LSTM model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,  # You can adjust based on convergence
    batch_size=16,  # Smaller batch size for augmented data
    verbose=1
)
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.7663 - mae: 0.8057 - val_loss: 0.7388 - val_mae: 0.8171
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6833 - mae: 0.7783 - val_loss: 0.5897 - val_mae: 0.7282
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4530 - mae: 0.5984 - val_loss: 0.4113 - val_mae: 0.5976
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3172 - mae: 0.4963 - val_loss: 0.2426 - val_mae: 0.3953
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1972 - mae: 0.3686 - val_loss: 0.1887 - val_mae: 0.2226
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1622 - mae: 0.2832 - val_loss: 0.1501 - val_mae: 0.2767
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1173 - mae: 0.2865 - val_loss: 0.1793 - val_mae: 0.3911
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1447 - mae: 0.3379 - val_loss: 0.1881 - val_mae: 0.4080
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1375 - mae: 0.3347 - val_loss: 0.1514 - val_mae: 0.3316
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1462 - mae: 0.2856 - val_loss: 0.1387 - val_mae: 0.2673
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1383 - mae: 0.2438 - val_loss: 0.1375 - val_mae: 0.2883
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1399 - mae: 0.2821 - val_loss: 0.1384 - val_mae: 0.3041
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1564 - mae: 0.2976 - val_loss: 0.1392 - val_mae: 0.3069
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1333 - mae: 0.2955 - val_loss: 0.1378 - val_mae: 0.2894
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1135 - mae: 0.2343 - val_loss: 0.1386 - val_mae: 0.2855
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1196 - mae: 0.2546 - val_loss: 0.1419 - val_mae: 0.3007
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1146 - mae: 0.2380 - val_loss: 0.1506 - val_mae: 0.3348
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1495 - mae: 0.3076 - val_loss: 0.1594 - val_mae: 0.3548
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1007 - mae: 0.2715 - val_loss: 0.1447 - val_mae: 0.3108
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1416 - mae: 0.2920 - val_loss: 0.1457 - val_mae: 0.3079
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1429 - mae: 0.2749 - val_loss: 0.1507 - val_mae: 0.3163
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1145 - mae: 0.2734 - val_loss: 0.1511 - val_mae: 0.3037
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1546 - mae: 0.3111 - val_loss: 0.1458 - val_mae: 0.2906
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1064 - mae: 0.2429 - val_loss: 0.1416 - val_mae: 0.2694
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1142 - mae: 0.2381 - val_loss: 0.1538 - val_mae: 0.3149
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1049 - mae: 0.2632 - val_loss: 0.1612 - val_mae: 0.3271
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1327 - mae: 0.2998 - val_loss: 0.1529 - val_mae: 0.2977
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1177 - mae: 0.2624 - val_loss: 0.1537 - val_mae: 0.2915
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1057 - mae: 0.2416 - val_loss: 0.1542 - val_mae: 0.2935
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.1423 - mae: 0.2953 - val_loss: 0.1469 - val_mae: 0.2909
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1122 - mae: 0.2602 - val_loss: 0.1374 - val_mae: 0.2792
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0978 - mae: 0.2415 - val_loss: 0.1350 - val_mae: 0.2867
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1126 - mae: 0.2746 - val_loss: 0.1342 - val_mae: 0.2774
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1021 - mae: 0.2424 - val_loss: 0.1281 - val_mae: 0.2375
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1104 - mae: 0.2578 - val_loss: 0.1238 - val_mae: 0.2267
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1090 - mae: 0.2521 - val_loss: 0.1293 - val_mae: 0.2493
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1445 - mae: 0.3034 - val_loss: 0.1449 - val_mae: 0.2948
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1074 - mae: 0.2680 - val_loss: 0.1400 - val_mae: 0.2634
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1048 - mae: 0.2602 - val_loss: 0.1374 - val_mae: 0.2624
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1044 - mae: 0.2570 - val_loss: 0.1295 - val_mae: 0.2543
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1260 - mae: 0.2813 - val_loss: 0.1249 - val_mae: 0.2503
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1114 - mae: 0.2434 - val_loss: 0.1225 - val_mae: 0.2516
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0994 - mae: 0.2493 - val_loss: 0.1205 - val_mae: 0.2512
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0997 - mae: 0.2417 - val_loss: 0.1212 - val_mae: 0.2488
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1209 - mae: 0.2667 - val_loss: 0.1295 - val_mae: 0.2547
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0902 - mae: 0.2265 - val_loss: 0.1346 - val_mae: 0.2559
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0979 - mae: 0.2163 - val_loss: 0.1376 - val_mae: 0.2595
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0921 - mae: 0.2275 - val_loss: 0.1394 - val_mae: 0.2879
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1142 - mae: 0.2637 - val_loss: 0.1331 - val_mae: 0.2823
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1071 - mae: 0.2589 - val_loss: 0.1179 - val_mae: 0.2360
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1204 - mae: 0.2624 - val_loss: 0.1074 - val_mae: 0.2203
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1179 - mae: 0.2793 - val_loss: 0.1143 - val_mae: 0.2521
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1197 - mae: 0.2679 - val_loss: 0.1132 - val_mae: 0.2420
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0933 - mae: 0.2244 - val_loss: 0.1097 - val_mae: 0.2328
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0958 - mae: 0.2383 - val_loss: 0.1085 - val_mae: 0.2305
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1177 - mae: 0.2626 - val_loss: 0.1106 - val_mae: 0.2295
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0902 - mae: 0.2153 - val_loss: 0.1150 - val_mae: 0.2335
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1030 - mae: 0.2555 - val_loss: 0.1210 - val_mae: 0.2658
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0898 - mae: 0.2230 - val_loss: 0.1085 - val_mae: 0.2361
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1031 - mae: 0.2525 - val_loss: 0.1092 - val_mae: 0.2460
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0894 - mae: 0.2220 - val_loss: 0.1102 - val_mae: 0.2365
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0935 - mae: 0.2441 - val_loss: 0.1115 - val_mae: 0.2326
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0973 - mae: 0.2250 - val_loss: 0.1160 - val_mae: 0.2369
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0891 - mae: 0.2257 - val_loss: 0.1316 - val_mae: 0.3035
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1191 - mae: 0.2787 - val_loss: 0.1227 - val_mae: 0.2795
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0965 - mae: 0.2483 - val_loss: 0.1108 - val_mae: 0.2273
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0733 - mae: 0.1945 - val_loss: 0.1129 - val_mae: 0.2193
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0890 - mae: 0.2171 - val_loss: 0.1125 - val_mae: 0.2215
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0850 - mae: 0.2204 - val_loss: 0.1095 - val_mae: 0.2260
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1108 - mae: 0.2551 - val_loss: 0.1044 - val_mae: 0.2268
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0967 - mae: 0.2404 - val_loss: 0.1073 - val_mae: 0.2160
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0930 - mae: 0.2210 - val_loss: 0.1101 - val_mae: 0.2279
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1097 - mae: 0.2315 - val_loss: 0.1071 - val_mae: 0.2406
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1069 - mae: 0.2348 - val_loss: 0.1031 - val_mae: 0.2307
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1081 - mae: 0.2546 - val_loss: 0.1031 - val_mae: 0.2176
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0907 - mae: 0.2334 - val_loss: 0.1043 - val_mae: 0.2230
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0881 - mae: 0.2026 - val_loss: 0.1161 - val_mae: 0.2593
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1032 - mae: 0.2356 - val_loss: 0.1082 - val_mae: 0.2451
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0869 - mae: 0.2323 - val_loss: 0.0961 - val_mae: 0.2239
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0877 - mae: 0.2214 - val_loss: 0.1070 - val_mae: 0.2386
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1124 - mae: 0.2562 - val_loss: 0.1036 - val_mae: 0.2550
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0894 - mae: 0.2208 - val_loss: 0.1154 - val_mae: 0.2750
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1407 - mae: 0.2682 - val_loss: 0.1164 - val_mae: 0.2381
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1561 - mae: 0.2743 - val_loss: 0.1063 - val_mae: 0.2304
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0741 - mae: 0.2081 - val_loss: 0.1101 - val_mae: 0.2259
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0797 - mae: 0.2053 - val_loss: 0.1141 - val_mae: 0.2201
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1237 - mae: 0.2623 - val_loss: 0.1184 - val_mae: 0.2418
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1018 - mae: 0.2353 - val_loss: 0.1271 - val_mae: 0.2829
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0786 - mae: 0.2187 - val_loss: 0.1266 - val_mae: 0.2803
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1090 - mae: 0.2588 - val_loss: 0.1199 - val_mae: 0.2460
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0986 - mae: 0.2380 - val_loss: 0.1141 - val_mae: 0.2392
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1194 - mae: 0.2532 - val_loss: 0.1135 - val_mae: 0.2329
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1074 - mae: 0.2343 - val_loss: 0.1173 - val_mae: 0.2342
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0845 - mae: 0.2179 - val_loss: 0.1351 - val_mae: 0.3011
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0975 - mae: 0.2442 - val_loss: 0.1296 - val_mae: 0.3028
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1141 - mae: 0.2484 - val_loss: 0.1065 - val_mae: 0.2417
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0898 - mae: 0.2298 - val_loss: 0.1107 - val_mae: 0.2379
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0915 - mae: 0.2364 - val_loss: 0.1434 - val_mae: 0.2799
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1140 - mae: 0.2530 - val_loss: 0.1423 - val_mae: 0.2700
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0869 - mae: 0.2126 - val_loss: 0.1079 - val_mae: 0.2374
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1010 - mae: 0.2341 - val_loss: 0.1063 - val_mae: 0.2542
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0801 - mae: 0.2246 - val_loss: 0.1094 - val_mae: 0.2595
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1064 - mae: 0.2581 - val_loss: 0.1022 - val_mae: 0.2246
# Epoch 104/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0910 - mae: 0.2279 - val_loss: 0.0993 - val_mae: 0.2133
# Epoch 105/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0849 - mae: 0.2147 - val_loss: 0.1010 - val_mae: 0.2091
# Epoch 106/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0929 - mae: 0.2124 - val_loss: 0.1108 - val_mae: 0.2703
# Epoch 107/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0971 - mae: 0.2394 - val_loss: 0.1277 - val_mae: 0.3076
# Epoch 108/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0853 - mae: 0.2409 - val_loss: 0.1066 - val_mae: 0.2360
# Epoch 109/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1122 - mae: 0.2175 - val_loss: 0.1160 - val_mae: 0.2128
# Epoch 110/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1226 - mae: 0.2305 - val_loss: 0.1410 - val_mae: 0.3248
# Epoch 111/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1285 - mae: 0.2658 - val_loss: 0.1571 - val_mae: 0.3573
# Epoch 112/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1216 - mae: 0.2627 - val_loss: 0.1324 - val_mae: 0.3082
# Epoch 113/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1320 - mae: 0.2788 - val_loss: 0.1219 - val_mae: 0.2675
# Epoch 114/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1062 - mae: 0.2201 - val_loss: 0.1229 - val_mae: 0.2402
# Epoch 115/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1254 - mae: 0.2588 - val_loss: 0.1343 - val_mae: 0.3016
# Epoch 116/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0845 - mae: 0.2233 - val_loss: 0.1460 - val_mae: 0.3320
# Epoch 117/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0963 - mae: 0.2384 - val_loss: 0.1241 - val_mae: 0.2930
# Epoch 118/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0863 - mae: 0.2334 - val_loss: 0.1103 - val_mae: 0.2290
# Epoch 119/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1069 - mae: 0.2378 - val_loss: 0.1073 - val_mae: 0.2215
# Epoch 120/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0965 - mae: 0.2425 - val_loss: 0.1127 - val_mae: 0.2542
# Epoch 121/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.1139 - mae: 0.2412 - val_loss: 0.1129 - val_mae: 0.2561
# Epoch 122/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0996 - mae: 0.2088 - val_loss: 0.1074 - val_mae: 0.2395
# Epoch 123/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1177 - mae: 0.2478 - val_loss: 0.1073 - val_mae: 0.2344
# Epoch 124/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0857 - mae: 0.2145 - val_loss: 0.1039 - val_mae: 0.2376
# Epoch 125/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0976 - mae: 0.2479 - val_loss: 0.1022 - val_mae: 0.2270
# Epoch 126/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1244 - mae: 0.2687 - val_loss: 0.1252 - val_mae: 0.2546
# Epoch 127/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1067 - mae: 0.2482 - val_loss: 0.1137 - val_mae: 0.2258
# Epoch 128/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0851 - mae: 0.2235 - val_loss: 0.1099 - val_mae: 0.2297
# Epoch 129/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0928 - mae: 0.2358 - val_loss: 0.1120 - val_mae: 0.2381
# Epoch 130/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0944 - mae: 0.2318 - val_loss: 0.1102 - val_mae: 0.2387
# Epoch 131/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0805 - mae: 0.2234 - val_loss: 0.1057 - val_mae: 0.2154
# Epoch 132/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0881 - mae: 0.2122 - val_loss: 0.1019 - val_mae: 0.2159
# Epoch 133/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0863 - mae: 0.2104 - val_loss: 0.0980 - val_mae: 0.2220
# Epoch 134/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0847 - mae: 0.2241 - val_loss: 0.0971 - val_mae: 0.2297
# Epoch 135/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0895 - mae: 0.2397 - val_loss: 0.0893 - val_mae: 0.2146
# Epoch 136/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1033 - mae: 0.2008 - val_loss: 0.0867 - val_mae: 0.2179
# Epoch 137/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0721 - mae: 0.2011 - val_loss: 0.0949 - val_mae: 0.2394
# Epoch 138/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0658 - mae: 0.1788 - val_loss: 0.0940 - val_mae: 0.2307
# Epoch 139/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0883 - mae: 0.2265 - val_loss: 0.0978 - val_mae: 0.2307
# Epoch 140/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0670 - mae: 0.2001 - val_loss: 0.0951 - val_mae: 0.2074
# Epoch 141/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0790 - mae: 0.2218 - val_loss: 0.0940 - val_mae: 0.1948
# Epoch 142/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0602 - mae: 0.2029 - val_loss: 0.0961 - val_mae: 0.2005
# Epoch 143/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0914 - mae: 0.2125 - val_loss: 0.0950 - val_mae: 0.1959
# Epoch 144/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0959 - mae: 0.2049 - val_loss: 0.0975 - val_mae: 0.2115
# Epoch 145/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0928 - mae: 0.2291 - val_loss: 0.0968 - val_mae: 0.2283
# Epoch 146/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0835 - mae: 0.2263 - val_loss: 0.0989 - val_mae: 0.2304
# Epoch 147/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0945 - mae: 0.2036 - val_loss: 0.0950 - val_mae: 0.2333
# Epoch 148/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0752 - mae: 0.2098 - val_loss: 0.0988 - val_mae: 0.2234
# Epoch 149/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0763 - mae: 0.2042 - val_loss: 0.0920 - val_mae: 0.2020
# Epoch 150/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0711 - mae: 0.1846 - val_loss: 0.1335 - val_mae: 0.2593
# Epoch 151/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1233 - mae: 0.2498 - val_loss: 0.1462 - val_mae: 0.2774
# Epoch 152/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0937 - mae: 0.2247 - val_loss: 0.1500 - val_mae: 0.2848
# Epoch 153/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1061 - mae: 0.2435 - val_loss: 0.1328 - val_mae: 0.2566
# Epoch 154/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1233 - mae: 0.2740 - val_loss: 0.1138 - val_mae: 0.2338
# Epoch 155/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0972 - mae: 0.2340 - val_loss: 0.1038 - val_mae: 0.2237
# Epoch 156/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0738 - mae: 0.2127 - val_loss: 0.1029 - val_mae: 0.2110
# Epoch 157/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0994 - mae: 0.2504 - val_loss: 0.0935 - val_mae: 0.2109
# Epoch 158/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0673 - mae: 0.1889 - val_loss: 0.0991 - val_mae: 0.2359
# Epoch 159/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0789 - mae: 0.2150 - val_loss: 0.0929 - val_mae: 0.2279
# Epoch 160/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0875 - mae: 0.2085 - val_loss: 0.0878 - val_mae: 0.2125
# Epoch 161/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0764 - mae: 0.1930 - val_loss: 0.0836 - val_mae: 0.1821
# Epoch 162/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0701 - mae: 0.1827 - val_loss: 0.0890 - val_mae: 0.2004
# Epoch 163/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1025 - mae: 0.2424 - val_loss: 0.0953 - val_mae: 0.2127
# Epoch 164/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0895 - mae: 0.2106 - val_loss: 0.0981 - val_mae: 0.2182
# Epoch 165/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0726 - mae: 0.2029 - val_loss: 0.0933 - val_mae: 0.2213
# Epoch 166/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0842 - mae: 0.2143 - val_loss: 0.0975 - val_mae: 0.2289
# Epoch 167/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0838 - mae: 0.2078 - val_loss: 0.0874 - val_mae: 0.2010
# Epoch 168/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0657 - mae: 0.1739 - val_loss: 0.0824 - val_mae: 0.1910
# Epoch 169/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0849 - mae: 0.1949 - val_loss: 0.0840 - val_mae: 0.2041
# Epoch 170/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0910 - mae: 0.2123 - val_loss: 0.0783 - val_mae: 0.1758
# Epoch 171/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0715 - mae: 0.1887 - val_loss: 0.0772 - val_mae: 0.1781
# Epoch 172/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0653 - mae: 0.1857 - val_loss: 0.0849 - val_mae: 0.2104
# Epoch 173/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0820 - mae: 0.2106 - val_loss: 0.0823 - val_mae: 0.2031
# Epoch 174/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0806 - mae: 0.1803 - val_loss: 0.0941 - val_mae: 0.2321
# Epoch 175/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0567 - mae: 0.1713 - val_loss: 0.1062 - val_mae: 0.2735
# Epoch 176/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0812 - mae: 0.2159 - val_loss: 0.1008 - val_mae: 0.2625
# Epoch 177/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0771 - mae: 0.2077 - val_loss: 0.0917 - val_mae: 0.2248
# Epoch 178/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0766 - mae: 0.2056 - val_loss: 0.0885 - val_mae: 0.1841
# Epoch 179/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0619 - mae: 0.1822 - val_loss: 0.0836 - val_mae: 0.1900
# Epoch 180/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0965 - mae: 0.2150 - val_loss: 0.0939 - val_mae: 0.2081
# Epoch 181/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0901 - mae: 0.2244 - val_loss: 0.0950 - val_mae: 0.1972
# Epoch 182/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0772 - mae: 0.2061 - val_loss: 0.0972 - val_mae: 0.2207
# Epoch 183/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0840 - mae: 0.2109 - val_loss: 0.0945 - val_mae: 0.2252
# Epoch 184/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0694 - mae: 0.1881 - val_loss: 0.0907 - val_mae: 0.2163
# Epoch 185/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0726 - mae: 0.1918 - val_loss: 0.0827 - val_mae: 0.1899
# Epoch 186/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0842 - mae: 0.1935 - val_loss: 0.0857 - val_mae: 0.1888
# Epoch 187/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0711 - mae: 0.1868 - val_loss: 0.0920 - val_mae: 0.2359
# Epoch 188/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0828 - mae: 0.2150 - val_loss: 0.0964 - val_mae: 0.2507
# Epoch 189/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0901 - mae: 0.2172 - val_loss: 0.0955 - val_mae: 0.2454
# Epoch 190/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0836 - mae: 0.2184 - val_loss: 0.0905 - val_mae: 0.2212
# Epoch 191/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0733 - mae: 0.1908 - val_loss: 0.0825 - val_mae: 0.1744
# Epoch 192/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0631 - mae: 0.1671 - val_loss: 0.0850 - val_mae: 0.1755
# Epoch 193/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0609 - mae: 0.1739 - val_loss: 0.0936 - val_mae: 0.2035
# Epoch 194/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0813 - mae: 0.2054 - val_loss: 0.0914 - val_mae: 0.2051
# Epoch 195/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0646 - mae: 0.1842 - val_loss: 0.0903 - val_mae: 0.2101
# Epoch 196/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0706 - mae: 0.1790 - val_loss: 0.0880 - val_mae: 0.2082
# Epoch 197/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0877 - mae: 0.2096 - val_loss: 0.0857 - val_mae: 0.2025
# Epoch 198/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0713 - mae: 0.1730 - val_loss: 0.0873 - val_mae: 0.2131
# Epoch 199/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0855 - mae: 0.1983 - val_loss: 0.0879 - val_mae: 0.2159
# Epoch 200/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1307 - mae: 0.2450 - val_loss: 0.0934 - val_mae: 0.2466
# Epoch 201/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0945 - mae: 0.2153 - val_loss: 0.0897 - val_mae: 0.2391
# Epoch 202/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0797 - mae: 0.1988 - val_loss: 0.0920 - val_mae: 0.2255
# Epoch 203/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0715 - mae: 0.1758 - val_loss: 0.0859 - val_mae: 0.2148
# Epoch 204/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0984 - mae: 0.2200 - val_loss: 0.1022 - val_mae: 0.2415
# Epoch 205/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0789 - mae: 0.1937 - val_loss: 0.0857 - val_mae: 0.1919
# Epoch 206/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0722 - mae: 0.1930 - val_loss: 0.1036 - val_mae: 0.2030
# Epoch 207/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0827 - mae: 0.1951 - val_loss: 0.0878 - val_mae: 0.2045
# Epoch 208/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0765 - mae: 0.2022 - val_loss: 0.1085 - val_mae: 0.2482
# Epoch 209/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0792 - mae: 0.2113 - val_loss: 0.0939 - val_mae: 0.2156
# Epoch 210/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0660 - mae: 0.1871 - val_loss: 0.0940 - val_mae: 0.2140
# Epoch 211/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0723 - mae: 0.1901 - val_loss: 0.0946 - val_mae: 0.2192
# Epoch 212/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0770 - mae: 0.2051 - val_loss: 0.0961 - val_mae: 0.2208
# Epoch 213/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0731 - mae: 0.2009 - val_loss: 0.0924 - val_mae: 0.2061
# Epoch 214/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0563 - mae: 0.1728 - val_loss: 0.0940 - val_mae: 0.2172
# Epoch 215/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0503 - mae: 0.1670 - val_loss: 0.0995 - val_mae: 0.2445
# Epoch 216/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0651 - mae: 0.1975 - val_loss: 0.1030 - val_mae: 0.2544
# Epoch 217/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0844 - mae: 0.2125 - val_loss: 0.0925 - val_mae: 0.2244
# Epoch 218/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0854 - mae: 0.2030 - val_loss: 0.0881 - val_mae: 0.2099
# Epoch 219/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0601 - mae: 0.1749 - val_loss: 0.0935 - val_mae: 0.2172
# Epoch 220/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0772 - mae: 0.2054 - val_loss: 0.0843 - val_mae: 0.1858
# Epoch 221/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0678 - mae: 0.1776 - val_loss: 0.0972 - val_mae: 0.2101
# Epoch 222/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1150 - mae: 0.2305 - val_loss: 0.0977 - val_mae: 0.2513
# Epoch 223/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0605 - mae: 0.1767 - val_loss: 0.0984 - val_mae: 0.2559
# Epoch 224/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0635 - mae: 0.1835 - val_loss: 0.0954 - val_mae: 0.2433
# Epoch 225/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0755 - mae: 0.2096 - val_loss: 0.0864 - val_mae: 0.2146
# Epoch 226/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0695 - mae: 0.1936 - val_loss: 0.0870 - val_mae: 0.2085
# Epoch 227/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0747 - mae: 0.2091 - val_loss: 0.0890 - val_mae: 0.2022
# Epoch 228/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0658 - mae: 0.1842 - val_loss: 0.0888 - val_mae: 0.2097
# Epoch 229/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0691 - mae: 0.1890 - val_loss: 0.0906 - val_mae: 0.2227
# Epoch 230/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0791 - mae: 0.1894 - val_loss: 0.1220 - val_mae: 0.2649
# Epoch 231/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1110 - mae: 0.2101 - val_loss: 0.1008 - val_mae: 0.2700
# Epoch 232/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0909 - mae: 0.2203 - val_loss: 0.1033 - val_mae: 0.2741
# Epoch 233/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0812 - mae: 0.2002 - val_loss: 0.0880 - val_mae: 0.2383
# Epoch 234/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0700 - mae: 0.1885 - val_loss: 0.0790 - val_mae: 0.2018
# Epoch 235/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0626 - mae: 0.1745 - val_loss: 0.0783 - val_mae: 0.1880
# Epoch 236/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0608 - mae: 0.1738 - val_loss: 0.0809 - val_mae: 0.1952
# Epoch 237/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0671 - mae: 0.1743 - val_loss: 0.0925 - val_mae: 0.2283
# Epoch 238/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0865 - mae: 0.2034 - val_loss: 0.0986 - val_mae: 0.2394
# Epoch 239/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1018 - mae: 0.1994 - val_loss: 0.1115 - val_mae: 0.2727
# Epoch 240/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1026 - mae: 0.2228 - val_loss: 0.1129 - val_mae: 0.2903
# Epoch 241/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0915 - mae: 0.2265 - val_loss: 0.1118 - val_mae: 0.2862
# Epoch 242/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0931 - mae: 0.2310 - val_loss: 0.0987 - val_mae: 0.2595
# Epoch 243/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0782 - mae: 0.1968 - val_loss: 0.0872 - val_mae: 0.2323
# Epoch 244/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0781 - mae: 0.1991 - val_loss: 0.0794 - val_mae: 0.2126
# Epoch 245/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0618 - mae: 0.1789 - val_loss: 0.0769 - val_mae: 0.2079
# Epoch 246/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0527 - mae: 0.1554 - val_loss: 0.0832 - val_mae: 0.2264
# Epoch 247/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0851 - mae: 0.2165 - val_loss: 0.0855 - val_mae: 0.2306
# Epoch 248/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0768 - mae: 0.1941 - val_loss: 0.0892 - val_mae: 0.2374
# Epoch 249/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0882 - mae: 0.2154 - val_loss: 0.0950 - val_mae: 0.2476
# Epoch 250/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0656 - mae: 0.1811 - val_loss: 0.0920 - val_mae: 0.2365
# Epoch 251/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0831 - mae: 0.2005 - val_loss: 0.1001 - val_mae: 0.2535
# Epoch 252/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0648 - mae: 0.1724 - val_loss: 0.0977 - val_mae: 0.2423
# Epoch 253/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0800 - mae: 0.1982 - val_loss: 0.1071 - val_mae: 0.2665
# Epoch 254/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0498 - mae: 0.1503 - val_loss: 0.0966 - val_mae: 0.2548
# Epoch 255/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0465 - mae: 0.1656 - val_loss: 0.0850 - val_mae: 0.2266
# Epoch 256/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0502 - mae: 0.1612 - val_loss: 0.0880 - val_mae: 0.2333
# Epoch 257/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0666 - mae: 0.1839 - val_loss: 0.0825 - val_mae: 0.2210
# Epoch 258/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0670 - mae: 0.1875 - val_loss: 0.0846 - val_mae: 0.2285
# Epoch 259/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0695 - mae: 0.2024 - val_loss: 0.0815 - val_mae: 0.2140
# Epoch 260/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0844 - mae: 0.2113 - val_loss: 0.0861 - val_mae: 0.2180
# Epoch 261/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0664 - mae: 0.1782 - val_loss: 0.0848 - val_mae: 0.2126
# Epoch 262/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0704 - mae: 0.1814 - val_loss: 0.0836 - val_mae: 0.2105
# Epoch 263/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0597 - mae: 0.1850 - val_loss: 0.0929 - val_mae: 0.2351
# Epoch 264/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0810 - mae: 0.2055 - val_loss: 0.0950 - val_mae: 0.2403
# Epoch 265/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0601 - mae: 0.1802 - val_loss: 0.0937 - val_mae: 0.2311
# Epoch 266/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0610 - mae: 0.1700 - val_loss: 0.0846 - val_mae: 0.2246
# Epoch 267/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0524 - mae: 0.1637 - val_loss: 0.0954 - val_mae: 0.2581
# Epoch 268/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0938 - mae: 0.2225 - val_loss: 0.0895 - val_mae: 0.2342
# Epoch 269/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0815 - mae: 0.2296 - val_loss: 0.0908 - val_mae: 0.2258
# Epoch 270/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0761 - mae: 0.1982 - val_loss: 0.0896 - val_mae: 0.2351
# Epoch 271/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0929 - mae: 0.2248 - val_loss: 0.0898 - val_mae: 0.2372
# Epoch 272/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0630 - mae: 0.1770 - val_loss: 0.0855 - val_mae: 0.2250
# Epoch 273/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0735 - mae: 0.1945 - val_loss: 0.0803 - val_mae: 0.2167
# Epoch 274/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0758 - mae: 0.1863 - val_loss: 0.0751 - val_mae: 0.2051
# Epoch 275/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0757 - mae: 0.1785 - val_loss: 0.0756 - val_mae: 0.2034
# Epoch 276/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0737 - mae: 0.1770 - val_loss: 0.0786 - val_mae: 0.2238
# Epoch 277/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0567 - mae: 0.1543 - val_loss: 0.0893 - val_mae: 0.2489
# Epoch 278/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0535 - mae: 0.1706 - val_loss: 0.0845 - val_mae: 0.2239
# Epoch 279/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0561 - mae: 0.1694 - val_loss: 0.0868 - val_mae: 0.2131
# Epoch 280/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0735 - mae: 0.1860 - val_loss: 0.0875 - val_mae: 0.2111
# Epoch 281/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0644 - mae: 0.1861 - val_loss: 0.0977 - val_mae: 0.2427
# Epoch 282/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0747 - mae: 0.1968 - val_loss: 0.0906 - val_mae: 0.2228
# Epoch 283/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0625 - mae: 0.1725 - val_loss: 0.0911 - val_mae: 0.2225
# Epoch 284/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0630 - mae: 0.1640 - val_loss: 0.0929 - val_mae: 0.2317
# Epoch 285/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0658 - mae: 0.1797 - val_loss: 0.0925 - val_mae: 0.2338
# Epoch 286/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0577 - mae: 0.1708 - val_loss: 0.0947 - val_mae: 0.2477
# Epoch 287/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0861 - mae: 0.2045 - val_loss: 0.0937 - val_mae: 0.2498
# Epoch 288/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0706 - mae: 0.1864 - val_loss: 0.0877 - val_mae: 0.2345
# Epoch 289/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0647 - mae: 0.1804 - val_loss: 0.0912 - val_mae: 0.2326
# Epoch 290/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0657 - mae: 0.1831 - val_loss: 0.0845 - val_mae: 0.2096
# Epoch 291/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0642 - mae: 0.1764 - val_loss: 0.0857 - val_mae: 0.2142
# Epoch 292/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0554 - mae: 0.1618 - val_loss: 0.0898 - val_mae: 0.2235
# Epoch 293/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0699 - mae: 0.1715 - val_loss: 0.1050 - val_mae: 0.2596
# Epoch 294/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0567 - mae: 0.1716 - val_loss: 0.1034 - val_mae: 0.2500
# Epoch 295/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0574 - mae: 0.1731 - val_loss: 0.1064 - val_mae: 0.2476
# Epoch 296/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0662 - mae: 0.1737 - val_loss: 0.0936 - val_mae: 0.2296
# Epoch 297/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0707 - mae: 0.1996 - val_loss: 0.0895 - val_mae: 0.2190
# Epoch 298/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0580 - mae: 0.1673 - val_loss: 0.0859 - val_mae: 0.2168
# Epoch 299/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0597 - mae: 0.1715 - val_loss: 0.0852 - val_mae: 0.2242
# Epoch 300/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0649 - mae: 0.1762 - val_loss: 0.0831 - val_mae: 0.2152
# Epoch 301/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0736 - mae: 0.1857 - val_loss: 0.0812 - val_mae: 0.2101
# Epoch 302/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0737 - mae: 0.1890 - val_loss: 0.0830 - val_mae: 0.2164
# Epoch 303/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0644 - mae: 0.1688 - val_loss: 0.0883 - val_mae: 0.2190
# Epoch 304/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0672 - mae: 0.1710 - val_loss: 0.0965 - val_mae: 0.2413
# Epoch 305/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0703 - mae: 0.1829 - val_loss: 0.0946 - val_mae: 0.2329
# Epoch 306/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0874 - mae: 0.2025 - val_loss: 0.0988 - val_mae: 0.2288
# Epoch 307/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0663 - mae: 0.1694 - val_loss: 0.0942 - val_mae: 0.2306
# Epoch 308/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0497 - mae: 0.1523 - val_loss: 0.0917 - val_mae: 0.2247
# Epoch 309/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0507 - mae: 0.1380 - val_loss: 0.0937 - val_mae: 0.2306
# Epoch 310/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0689 - mae: 0.1816 - val_loss: 0.0894 - val_mae: 0.2268
# Epoch 311/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0722 - mae: 0.1845 - val_loss: 0.0911 - val_mae: 0.2193
# Epoch 312/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0775 - mae: 0.1871 - val_loss: 0.0883 - val_mae: 0.2144
# Epoch 313/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0501 - mae: 0.1480 - val_loss: 0.0870 - val_mae: 0.2163
# Epoch 314/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0572 - mae: 0.1578 - val_loss: 0.0896 - val_mae: 0.2194
# Epoch 315/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0611 - mae: 0.1787 - val_loss: 0.0958 - val_mae: 0.2274
# Epoch 316/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0677 - mae: 0.1735 - val_loss: 0.0993 - val_mae: 0.2428
# Epoch 317/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0711 - mae: 0.1795 - val_loss: 0.1096 - val_mae: 0.2537
# Epoch 318/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0984 - mae: 0.1959 - val_loss: 0.0987 - val_mae: 0.2429
# Epoch 319/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0759 - mae: 0.1855 - val_loss: 0.0917 - val_mae: 0.2416
# Epoch 320/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0825 - mae: 0.1996 - val_loss: 0.1050 - val_mae: 0.2636
# Epoch 321/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0746 - mae: 0.1936 - val_loss: 0.0854 - val_mae: 0.2142
# Epoch 322/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0831 - mae: 0.1922 - val_loss: 0.0883 - val_mae: 0.2119
# Epoch 323/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1014 - mae: 0.2003 - val_loss: 0.0897 - val_mae: 0.2290
# Epoch 324/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0724 - mae: 0.1696 - val_loss: 0.0989 - val_mae: 0.2470
# Epoch 325/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0786 - mae: 0.1865 - val_loss: 0.1027 - val_mae: 0.2529
# Epoch 326/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0496 - mae: 0.1568 - val_loss: 0.0992 - val_mae: 0.2395
# Epoch 327/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0619 - mae: 0.1671 - val_loss: 0.0954 - val_mae: 0.2294
# Epoch 328/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0736 - mae: 0.1878 - val_loss: 0.0998 - val_mae: 0.2404
# Epoch 329/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0776 - mae: 0.1821 - val_loss: 0.0955 - val_mae: 0.2363
# Epoch 330/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0737 - mae: 0.1743 - val_loss: 0.0889 - val_mae: 0.2262
# Epoch 331/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0515 - mae: 0.1569 - val_loss: 0.1047 - val_mae: 0.2567
# Epoch 332/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0758 - mae: 0.1883 - val_loss: 0.0910 - val_mae: 0.2357
# Epoch 333/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0688 - mae: 0.1685 - val_loss: 0.0935 - val_mae: 0.2322
# Epoch 334/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0824 - mae: 0.1958 - val_loss: 0.0971 - val_mae: 0.2389
# Epoch 335/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0702 - mae: 0.1769 - val_loss: 0.0981 - val_mae: 0.2359
# Epoch 336/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0587 - mae: 0.1641 - val_loss: 0.0989 - val_mae: 0.2249
# Epoch 337/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0587 - mae: 0.1546 - val_loss: 0.1002 - val_mae: 0.2263
# Epoch 338/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0551 - mae: 0.1492 - val_loss: 0.1049 - val_mae: 0.2356
# Epoch 339/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0456 - mae: 0.1440 - val_loss: 0.1096 - val_mae: 0.2473
# Epoch 340/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0376 - mae: 0.1323 - val_loss: 0.1180 - val_mae: 0.2627
# Epoch 341/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0610 - mae: 0.1718 - val_loss: 0.1237 - val_mae: 0.2540
# Epoch 342/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0653 - mae: 0.1760 - val_loss: 0.1158 - val_mae: 0.2399
# Epoch 343/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0660 - mae: 0.1806 - val_loss: 0.1139 - val_mae: 0.2373
# Epoch 344/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0667 - mae: 0.1749 - val_loss: 0.1056 - val_mae: 0.2338
# Epoch 345/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0518 - mae: 0.1479 - val_loss: 0.1140 - val_mae: 0.2362
# Epoch 346/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0543 - mae: 0.1501 - val_loss: 0.1108 - val_mae: 0.2372
# Epoch 347/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0494 - mae: 0.1317 - val_loss: 0.1015 - val_mae: 0.2476
# Epoch 348/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0485 - mae: 0.1482 - val_loss: 0.0997 - val_mae: 0.2352
# Epoch 349/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0695 - mae: 0.1636 - val_loss: 0.1209 - val_mae: 0.2641
# Epoch 350/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1100 - mae: 0.2182 - val_loss: 0.1144 - val_mae: 0.2823
# Epoch 351/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0564 - mae: 0.1684 - val_loss: 0.1127 - val_mae: 0.2828
# Epoch 352/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0431 - mae: 0.1367 - val_loss: 0.1032 - val_mae: 0.2525
# Epoch 353/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0823 - mae: 0.1771 - val_loss: 0.1080 - val_mae: 0.2633
# Epoch 354/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0755 - mae: 0.1809 - val_loss: 0.1014 - val_mae: 0.2586
# Epoch 355/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0717 - mae: 0.2009 - val_loss: 0.0986 - val_mae: 0.2622
# Epoch 356/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0657 - mae: 0.1711 - val_loss: 0.0884 - val_mae: 0.2418
# Epoch 357/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0554 - mae: 0.1705 - val_loss: 0.0813 - val_mae: 0.2200
# Epoch 358/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0723 - mae: 0.1836 - val_loss: 0.0827 - val_mae: 0.2227
# Epoch 359/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0675 - mae: 0.1840 - val_loss: 0.0802 - val_mae: 0.2115
# Epoch 360/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0689 - mae: 0.1731 - val_loss: 0.0842 - val_mae: 0.2239
# Epoch 361/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0726 - mae: 0.1751 - val_loss: 0.0876 - val_mae: 0.2335
# Epoch 362/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0533 - mae: 0.1633 - val_loss: 0.0858 - val_mae: 0.2267
# Epoch 363/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0800 - mae: 0.1791 - val_loss: 0.0996 - val_mae: 0.2562
# Epoch 364/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0591 - mae: 0.1641 - val_loss: 0.0904 - val_mae: 0.2289
# Epoch 365/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0536 - mae: 0.1617 - val_loss: 0.0860 - val_mae: 0.2052
# Epoch 366/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0625 - mae: 0.1687 - val_loss: 0.0872 - val_mae: 0.2093
# Epoch 367/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0660 - mae: 0.1748 - val_loss: 0.0916 - val_mae: 0.2322
# Epoch 368/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0465 - mae: 0.1482 - val_loss: 0.0912 - val_mae: 0.2277
# Epoch 369/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0455 - mae: 0.1420 - val_loss: 0.1065 - val_mae: 0.2496
# Epoch 370/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0835 - mae: 0.1847 - val_loss: 0.1036 - val_mae: 0.2552
# Epoch 371/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0634 - mae: 0.1631 - val_loss: 0.1116 - val_mae: 0.2826
# Epoch 372/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0655 - mae: 0.1799 - val_loss: 0.1080 - val_mae: 0.2623
# Epoch 373/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0556 - mae: 0.1741 - val_loss: 0.0969 - val_mae: 0.2319
# Epoch 374/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0674 - mae: 0.1829 - val_loss: 0.0872 - val_mae: 0.1965
# Epoch 375/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0748 - mae: 0.1968 - val_loss: 0.0765 - val_mae: 0.1828
# Epoch 376/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0727 - mae: 0.1783 - val_loss: 0.0724 - val_mae: 0.1887
# Epoch 377/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0759 - mae: 0.1761 - val_loss: 0.0762 - val_mae: 0.2143
# Epoch 378/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0664 - mae: 0.1763 - val_loss: 0.0803 - val_mae: 0.2230
# Epoch 379/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0522 - mae: 0.1517 - val_loss: 0.0800 - val_mae: 0.2213
# Epoch 380/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0379 - mae: 0.1400 - val_loss: 0.0838 - val_mae: 0.2393
# Epoch 381/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0852 - mae: 0.2015 - val_loss: 0.0821 - val_mae: 0.2338
# Epoch 382/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0583 - mae: 0.1684 - val_loss: 0.0931 - val_mae: 0.2367
# Epoch 383/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0892 - mae: 0.1925 - val_loss: 0.0959 - val_mae: 0.2330
# Epoch 384/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0641 - mae: 0.1811 - val_loss: 0.0979 - val_mae: 0.2273
# Epoch 385/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0600 - mae: 0.1815 - val_loss: 0.1006 - val_mae: 0.2271
# Epoch 386/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0481 - mae: 0.1530 - val_loss: 0.1006 - val_mae: 0.2417
# Epoch 387/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0566 - mae: 0.1710 - val_loss: 0.1033 - val_mae: 0.2614
# Epoch 388/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0689 - mae: 0.1856 - val_loss: 0.1100 - val_mae: 0.2682
# Epoch 389/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0622 - mae: 0.1796 - val_loss: 0.0970 - val_mae: 0.2522
# Epoch 390/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0723 - mae: 0.1908 - val_loss: 0.0895 - val_mae: 0.2360
# Epoch 391/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0690 - mae: 0.1799 - val_loss: 0.0822 - val_mae: 0.2071
# Epoch 392/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0639 - mae: 0.1779 - val_loss: 0.0842 - val_mae: 0.2076
# Epoch 393/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0446 - mae: 0.1456 - val_loss: 0.0956 - val_mae: 0.2531
# Epoch 394/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0820 - mae: 0.1782 - val_loss: 0.1073 - val_mae: 0.2803
# Epoch 395/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0728 - mae: 0.1923 - val_loss: 0.0943 - val_mae: 0.2404
# Epoch 396/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0530 - mae: 0.1535 - val_loss: 0.1013 - val_mae: 0.2395
# Epoch 397/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0818 - mae: 0.1888 - val_loss: 0.0879 - val_mae: 0.2207
# Epoch 398/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0669 - mae: 0.1813 - val_loss: 0.0805 - val_mae: 0.2102
# Epoch 399/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0741 - mae: 0.1891 - val_loss: 0.0783 - val_mae: 0.2043
# Epoch 400/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0693 - mae: 0.1741 - val_loss: 0.0756 - val_mae: 0.1920
# Epoch 401/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0588 - mae: 0.1660 - val_loss: 0.0770 - val_mae: 0.1921
# Epoch 402/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0636 - mae: 0.1631 - val_loss: 0.0764 - val_mae: 0.2038
# Epoch 403/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0637 - mae: 0.1692 - val_loss: 0.0799 - val_mae: 0.2150
# Epoch 404/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0488 - mae: 0.1544 - val_loss: 0.0800 - val_mae: 0.2115
# Epoch 405/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0724 - mae: 0.1833 - val_loss: 0.0780 - val_mae: 0.1926
# Epoch 406/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0379 - mae: 0.1213 - val_loss: 0.0777 - val_mae: 0.1874
# Epoch 407/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0557 - mae: 0.1629 - val_loss: 0.0780 - val_mae: 0.1870
# Epoch 408/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0483 - mae: 0.1487 - val_loss: 0.0814 - val_mae: 0.1994
# Epoch 409/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0519 - mae: 0.1564 - val_loss: 0.0879 - val_mae: 0.2078
# Epoch 410/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0663 - mae: 0.1720 - val_loss: 0.0933 - val_mae: 0.2120
# Epoch 411/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0703 - mae: 0.1819 - val_loss: 0.0968 - val_mae: 0.2129
# Epoch 412/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0545 - mae: 0.1631 - val_loss: 0.0993 - val_mae: 0.2063
# Epoch 413/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0530 - mae: 0.1510 - val_loss: 0.1032 - val_mae: 0.2144
# Epoch 414/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0552 - mae: 0.1637 - val_loss: 0.1054 - val_mae: 0.2228
# Epoch 415/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0574 - mae: 0.1625 - val_loss: 0.1070 - val_mae: 0.2366
# Epoch 416/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0518 - mae: 0.1509 - val_loss: 0.1045 - val_mae: 0.2435
# Epoch 417/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0510 - mae: 0.1621 - val_loss: 0.1029 - val_mae: 0.2440
# Epoch 418/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0563 - mae: 0.1560 - val_loss: 0.0999 - val_mae: 0.2217
# Epoch 419/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0543 - mae: 0.1623 - val_loss: 0.0994 - val_mae: 0.2228
# Epoch 420/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0537 - mae: 0.1506 - val_loss: 0.0976 - val_mae: 0.2234
# Epoch 421/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0592 - mae: 0.1495 - val_loss: 0.0966 - val_mae: 0.2134
# Epoch 422/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0671 - mae: 0.1730 - val_loss: 0.1064 - val_mae: 0.2363
# Epoch 423/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0771 - mae: 0.1797 - val_loss: 0.1033 - val_mae: 0.2450
# Epoch 424/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0568 - mae: 0.1613 - val_loss: 0.1086 - val_mae: 0.2598
# Epoch 425/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0311 - mae: 0.1288 - val_loss: 0.1058 - val_mae: 0.2585
# Epoch 426/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0652 - mae: 0.1709 - val_loss: 0.0994 - val_mae: 0.2480
# Epoch 427/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0564 - mae: 0.1719 - val_loss: 0.0861 - val_mae: 0.2094
# Epoch 428/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0513 - mae: 0.1508 - val_loss: 0.0830 - val_mae: 0.2035
# Epoch 429/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0426 - mae: 0.1298 - val_loss: 0.0806 - val_mae: 0.2004
# Epoch 430/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0637 - mae: 0.1530 - val_loss: 0.0801 - val_mae: 0.2047
# Epoch 431/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0584 - mae: 0.1546 - val_loss: 0.0871 - val_mae: 0.2277
# Epoch 432/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0640 - mae: 0.1661 - val_loss: 0.0951 - val_mae: 0.2369
# Epoch 433/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0649 - mae: 0.1676 - val_loss: 0.1016 - val_mae: 0.2396
# Epoch 434/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0517 - mae: 0.1472 - val_loss: 0.1013 - val_mae: 0.2200
# Epoch 435/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0547 - mae: 0.1454 - val_loss: 0.1008 - val_mae: 0.2197
# Epoch 436/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0613 - mae: 0.1541 - val_loss: 0.0986 - val_mae: 0.2337
# Epoch 437/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0382 - mae: 0.1371 - val_loss: 0.0927 - val_mae: 0.2329
# Epoch 438/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0479 - mae: 0.1500 - val_loss: 0.0934 - val_mae: 0.2266
# Epoch 439/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0485 - mae: 0.1558 - val_loss: 0.0975 - val_mae: 0.2361
# Epoch 440/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0511 - mae: 0.1474 - val_loss: 0.0975 - val_mae: 0.2369
# Epoch 441/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0566 - mae: 0.1582 - val_loss: 0.0969 - val_mae: 0.2318
# Epoch 442/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0387 - mae: 0.1286 - val_loss: 0.0948 - val_mae: 0.2221
# Epoch 443/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0411 - mae: 0.1201 - val_loss: 0.0991 - val_mae: 0.2351
# Epoch 444/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0540 - mae: 0.1576 - val_loss: 0.1057 - val_mae: 0.2529
# Epoch 445/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0418 - mae: 0.1398 - val_loss: 0.1065 - val_mae: 0.2538
# Epoch 446/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0456 - mae: 0.1377 - val_loss: 0.1057 - val_mae: 0.2449
# Epoch 447/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0437 - mae: 0.1406 - val_loss: 0.1032 - val_mae: 0.2410
# Epoch 448/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0650 - mae: 0.1671 - val_loss: 0.1014 - val_mae: 0.2353
# Epoch 449/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0491 - mae: 0.1360 - val_loss: 0.1031 - val_mae: 0.2349
# Epoch 450/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0480 - mae: 0.1428 - val_loss: 0.1067 - val_mae: 0.2436
# Epoch 451/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0616 - mae: 0.1603 - val_loss: 0.1128 - val_mae: 0.2592
# Epoch 452/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0468 - mae: 0.1436 - val_loss: 0.1155 - val_mae: 0.2630
# Epoch 453/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0575 - mae: 0.1464 - val_loss: 0.1136 - val_mae: 0.2532
# Epoch 454/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0598 - mae: 0.1456 - val_loss: 0.1071 - val_mae: 0.2363
# Epoch 455/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0515 - mae: 0.1487 - val_loss: 0.1027 - val_mae: 0.2264
# Epoch 456/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0451 - mae: 0.1297 - val_loss: 0.1047 - val_mae: 0.2401
# Epoch 457/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0593 - mae: 0.1676 - val_loss: 0.1088 - val_mae: 0.2458
# Epoch 458/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0607 - mae: 0.1536 - val_loss: 0.1046 - val_mae: 0.2447
# Epoch 459/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0424 - mae: 0.1292 - val_loss: 0.0975 - val_mae: 0.2522
# Epoch 460/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0502 - mae: 0.1476 - val_loss: 0.0892 - val_mae: 0.2348
# Epoch 461/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0564 - mae: 0.1348 - val_loss: 0.0804 - val_mae: 0.2258
# Epoch 462/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0680 - mae: 0.1651 - val_loss: 0.0770 - val_mae: 0.2270
# Epoch 463/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0533 - mae: 0.1545 - val_loss: 0.0783 - val_mae: 0.2243
# Epoch 464/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0577 - mae: 0.1688 - val_loss: 0.0821 - val_mae: 0.2267
# Epoch 465/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0532 - mae: 0.1524 - val_loss: 0.0816 - val_mae: 0.2172
# Epoch 466/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0552 - mae: 0.1582 - val_loss: 0.0817 - val_mae: 0.2072
# Epoch 467/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0588 - mae: 0.1600 - val_loss: 0.0847 - val_mae: 0.2139
# Epoch 468/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0457 - mae: 0.1463 - val_loss: 0.0857 - val_mae: 0.2153
# Epoch 469/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0631 - mae: 0.1655 - val_loss: 0.0869 - val_mae: 0.2216
# Epoch 470/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0547 - mae: 0.1445 - val_loss: 0.0858 - val_mae: 0.2216
# Epoch 471/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0446 - mae: 0.1342 - val_loss: 0.0841 - val_mae: 0.2226
# Epoch 472/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0530 - mae: 0.1532 - val_loss: 0.0836 - val_mae: 0.2218
# Epoch 473/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0317 - mae: 0.1186 - val_loss: 0.0837 - val_mae: 0.2140
# Epoch 474/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0469 - mae: 0.1368 - val_loss: 0.0890 - val_mae: 0.2245
# Epoch 475/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0709 - mae: 0.1705 - val_loss: 0.0956 - val_mae: 0.2294
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0494 - mae: 0.1364 - val_loss: 0.1027 - val_mae: 0.2393
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0613 - mae: 0.1513 - val_loss: 0.1083 - val_mae: 0.2524
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0428 - mae: 0.1474 - val_loss: 0.1080 - val_mae: 0.2532
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0541 - mae: 0.1484 - val_loss: 0.1051 - val_mae: 0.2422
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0502 - mae: 0.1536 - val_loss: 0.1023 - val_mae: 0.2283
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0529 - mae: 0.1563 - val_loss: 0.1017 - val_mae: 0.2300
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0493 - mae: 0.1475 - val_loss: 0.1053 - val_mae: 0.2424
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0576 - mae: 0.1591 - val_loss: 0.1073 - val_mae: 0.2446
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0320 - mae: 0.1150 - val_loss: 0.1103 - val_mae: 0.2443
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0440 - mae: 0.1316 - val_loss: 0.1112 - val_mae: 0.2423
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0433 - mae: 0.1413 - val_loss: 0.1126 - val_mae: 0.2516
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0570 - mae: 0.1547 - val_loss: 0.1149 - val_mae: 0.2606
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0645 - mae: 0.1569 - val_loss: 0.1123 - val_mae: 0.2620
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0665 - mae: 0.1630 - val_loss: 0.1073 - val_mae: 0.2523
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0523 - mae: 0.1520 - val_loss: 0.0998 - val_mae: 0.2378
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0413 - mae: 0.1345 - val_loss: 0.0969 - val_mae: 0.2361
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0551 - mae: 0.1496 - val_loss: 0.0991 - val_mae: 0.2418
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0589 - mae: 0.1476 - val_loss: 0.0989 - val_mae: 0.2427
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0631 - mae: 0.1581 - val_loss: 0.0994 - val_mae: 0.2475
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0680 - mae: 0.1534 - val_loss: 0.1047 - val_mae: 0.2555
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0573 - mae: 0.1437 - val_loss: 0.1083 - val_mae: 0.2550
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0500 - mae: 0.1386 - val_loss: 0.1082 - val_mae: 0.2499
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0607 - mae: 0.1533 - val_loss: 0.1136 - val_mae: 0.2530
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0530 - mae: 0.1487 - val_loss: 0.1192 - val_mae: 0.2580
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0696 - mae: 0.1670 - val_loss: 0.1219 - val_mae: 0.2595

# %%
val_loss, val_mae = model.evaluate(X_val, y_val, verbose=0)
print(f"Validation Loss: {val_loss:.4f}, Validation MAE: {val_mae:.4f}")
# Out:
# Validation Loss: 0.1219, Validation MAE: 0.2595

# %%
# Predict scores on validation data
predictions = model.predict(X_val)

# Print predictions vs. actual
for i, pred in enumerate(predictions):
    print(f"Predicted: {pred[0]:.2f}, Actual: {y_val[i]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Predicted: 0.83, Actual: 1.00
# Predicted: 0.07, Actual: 1.00
# Predicted: 0.84, Actual: 1.00
# Predicted: 0.85, Actual: 1.00
# Predicted: -0.09, Actual: 0.00
# Predicted: 0.67, Actual: 1.00
# Predicted: 0.81, Actual: 1.00
# Predicted: 0.91, Actual: 1.00
# Predicted: 0.67, Actual: 0.50
# Predicted: 0.67, Actual: 1.00
# Predicted: 0.83, Actual: 1.00
# Predicted: 0.83, Actual: 1.00
# Predicted: 0.83, Actual: 1.00
# Predicted: 0.83, Actual: 1.00
# Predicted: 0.84, Actual: 1.00
# Predicted: 0.86, Actual: 0.00
# Predicted: 0.84, Actual: 1.00
# Predicted: 0.83, Actual: 1.00

# %%
# Scatter plot of predictions vs. actual
import matplotlib.pyplot as plt

plt.scatter(y_val, predictions, c='blue', label='Predicted vs Actual')
plt.plot([0, 1], [0, 1], 'r--', label='Perfect Match')  # Reference line
plt.xlabel('Actual Scores')
plt.ylabel('Predicted Scores')
plt.title('Model Predictions vs. Actual Scores')
plt.legend()
plt.show()

# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Function to check if the discus is released via index finger
def is_discus_released(index_finger, wrist):
    """
    Determines if the discus is released via index finger by analyzing 
    the relative positions of the index finger and wrist.
    Conditions:
    - The index finger should extend beyond the wrist in the x-direction.
    - The vertical displacement should be minimal.
    """
    index_x, index_y = index_finger
    wrist_x, wrist_y = wrist

    # Release condition: index finger should extend forward with minimal vertical displacement
    return index_x > wrist_x and abs(index_y - wrist_y) < 0.05

# Path for the new test video
new_video_path = "/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/disc_throwing/stages/stage5/test_videos/1_user2.mp4"

# Extract keypoints for the new video
new_keypoints = []
cap = cv2.VideoCapture(new_video_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to RGB for MediaPipe processing
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = pose.process(frame_rgb)

    if result.pose_landmarks:
        landmarks = result.pose_landmarks.landmark

        # Extract keypoints for discus release analysis
        left_index_finger = [landmarks[mp_pose.PoseLandmark.LEFT_INDEX].x,
                             landmarks[mp_pose.PoseLandmark.LEFT_INDEX].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST].x,
                      landmarks[mp_pose.PoseLandmark.LEFT_WRIST].y]

        right_index_finger = [landmarks[mp_pose.PoseLandmark.RIGHT_INDEX].x,
                              landmarks[mp_pose.PoseLandmark.RIGHT_INDEX].y]
        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST].x,
                       landmarks[mp_pose.PoseLandmark.RIGHT_WRIST].y]

        # Check for discus release via index finger on both hands
        left_release = is_discus_released(left_index_finger, left_wrist)
        right_release = is_discus_released(right_index_finger, right_wrist)

        # Store binary values (0 or 1) for analysis, using only one feature if necessary
        new_keypoints.append([int(left_release)])

cap.release()

# Ensure consistent input shape with training
max_seq_length = 33  # Adjust based on training sequence length
num_features = model.input_shape[-1]  # Get feature count from model input

# Pad sequence to required length
new_keypoints_padded = pad_sequences([new_keypoints], maxlen=max_seq_length, padding='post', dtype='float32')

# Reshape to match model input (samples, timesteps, features)
new_keypoints_padded = new_keypoints_padded.reshape((1, max_seq_length, num_features))

print(f"Input shape for prediction: {new_keypoints_padded.shape}")

# Predict score for the new video
predicted_score = model.predict(new_keypoints_padded)
print(f"Predicted Score: {predicted_score[0][0]:.2f}")
# Out:
# Input shape for prediction: (1, 33, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Score: 0.83
# I0000 00:00:1737673314.347100 12325729 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M4 Pro
# W0000 00:00:1737673314.406907 12426329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737673314.418655 12426328 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
print(X_train.shape[1])
# Out:
# 33

# %%
def classify_score(prediction):
    """Classify the prediction into 0, 0.5, or 1 based on thresholds."""
    if prediction >= 0.65:
        return 1.0
    elif prediction >= 0.4:
        return 0.5
    else:
        return 0.0

# %%
# Predict scores on validation data
predictions = model.predict(X_val)

# Apply classification logic
classified_predictions = [classify_score(pred[0]) for pred in predictions]

# Print classified predictions vs actual scores
for i, (pred, actual) in enumerate(zip(classified_predictions, y_val)):
    print(f"Classified: {pred}, Actual: {actual}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Classified: 1.0, Actual: 1.0
# Classified: 0.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 0.0, Actual: 0.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 0.5
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 0.0
# Classified: 1.0, Actual: 1.0
# Classified: 1.0, Actual: 1.0

# %%
import tensorflow.keras.backend as K

def weighted_mse(y_true, y_pred):
    """Weighted Mean Squared Error to prioritize true negatives."""
    weights = K.switch(y_true < 0.70, 2.0, 1.0)  # Weight true negatives higher
    return K.mean(weights * K.square(y_true - y_pred))

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss=weighted_mse, metrics=['mae'])

# %%
# Predict and classify scores
classified_predictions = [classify_score(pred[0]) for pred in model.predict(X_val)]

# Evaluate accuracy of classification
correct = sum(1 for pred, actual in zip(classified_predictions, y_val) if pred == actual)
accuracy = correct / len(y_val)

print(f"Classification Accuracy: {accuracy:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Classification Accuracy: 0.83

# %%
model.save("/Users/danyukezz/Desktop/2 year 1 semester/team project/danya_preprocessing_sports/disc_throwing/stages/stage5/models/discus_stage5.keras")
